# %% [markdown]
# ### Imports

# %%
#Spark Imports
import pyspark
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.window import Window
from pyspark.sql import functions as F
from pyspark.sql import types as T

#Python Standard Libs Imports
import json
import urllib2
import sys
from datetime import datetime
from os.path import isfile, join, splitext
from glob import glob

#Imports to enable visualizations
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Functions

# %% [markdown]
# #### Basic Functions

# %%
def rename_columns(df, list_of_tuples):
    for (old_col, new_col) in list_of_tuples:
        df = df.withColumnRenamed(old_col, new_col)
    return df

def read_folders(path, sqlContext, sc, initial_date, final_date, folder_suffix):
    extension = splitext(path)[1]

    if extension == "":
        path_pattern = path + "/*/part-*"
        if "hdfs" in path:
            URI = sc._gateway.jvm.java.net.URI
            Path = sc._gateway.jvm.org.apache.hadoop.fs.Path
            FileSystem = sc._gateway.jvm.org.apache.hadoop.fs.FileSystem
            Configuration = sc._gateway.jvm.org.apache.hadoop.conf.Configuration

            hdfs = "/".join(path_pattern.split("/")[:3])
            dir = "/" + "/".join(path_pattern.split("/")[3:])

            fs = FileSystem.get(URI(hdfs), Configuration())

            status = fs.globStatus(Path(dir))

            files = map(lambda file_status: str(file_status.getPath()), status)

        else:
            files = glob(path_pattern)

        #print initial_date, final_date
        #print datetime.strptime(files[0].split('/')[-2],('%Y_%m_%d' + folder_suffix))

        files = filter(lambda f: initial_date <= datetime.strptime(f.split("/")[-2], ('%Y_%m_%d' + folder_suffix)) <=
                                 final_date, files)
        
        #print len(files)
        #print files
        if folder_suffix == '_od':
            return reduce(lambda df1, df2: df1.unionAll(df2),
                      map(lambda f: read_hdfs_folder(sqlContext,f), files))
        else:
            return reduce(lambda df1, df2: df1.unionAll(df2),
                      map(lambda f: read_buste_data_v3(sqlContext,f), files))
    else:
        return read_file(path, sqlContext)

def read_hdfs_folder(sqlContext, folderpath):
    data_frame = sqlContext.read.csv(folderpath, header=True,
                                     inferSchema=True,nullValue="-")
    return data_frame

def read_buste_data_v3(sqlContext, folderpath):
    data_frame = read_hdfs_folder(sqlContext,folderpath)
    data_frame = data_frame.withColumn("date", F.unix_timestamp(F.col("date"),'yyyy_MM_dd'))
    
    return data_frame

def printdf(df,l=10):
    return df.limit(l).toPandas()

def get_timestamp_in_tz(unixtime_timestamp,ts_format,tz):
    return F.from_utc_timestamp(F.from_unixtime(unixtime_timestamp, ts_format),tz)

# %% [markdown]
# #### OTP Functions

# %%
def get_router_id(query_date):
    INTERMEDIATE_OTP_DATE = datetime.strptime("2017-06-30", "%Y-%m-%d")
    
    router_id = ''
    date_timestamp = datetime.strptime(query_date, "%Y-%m-%d")   
    
    if (date_timestamp <= INTERMEDIATE_OTP_DATE):
        return 'ctba-2017-1'
    else:
        return 'ctba-2017-2'

def get_otp_itineraries(otp_url,o_lat,o_lon,d_lat,d_lon,date,time,verbose=False):
    otp_http_request = 'routers/{}/plan?fromPlace={},{}&toPlace={},{}&mode=TRANSIT,WALK&date={}&time={}'
	
    router_id = get_router_id(date)
    otp_request_url = otp_url + otp_http_request.format(router_id,o_lat,o_lon,d_lat,d_lon,date,time)
    if verbose:
        print otp_request_url
    return json.loads(urllib2.urlopen(otp_request_url).read())

def get_executed_trip_schedule(otp_url,o_lat,o_lon,d_lat,d_lon,date,time,route,start_stop_id,verbose=False):
    DEF_AGENCY_NAME = 'URBS'
    DEF_AGENCY_ID = 1
    otp_http_request = 'routers/{}/plan?fromPlace={},{}&toPlace={},{}&mode=TRANSIT,WALK&date={}&time={}&numItineraries=1&preferredRoutes={}_{}&startTransitStopId={}_{}&maxWalkingDistance=150&maxTransfers=0'
    
    router_id = get_router_id(date)
    otp_request_url = otp_url + otp_http_request.format(router_id,o_lat,o_lon,d_lat,d_lon,date,time,DEF_AGENCY_NAME,route,DEF_AGENCY_ID,start_stop_id)
    if verbose:
        print otp_request_url
    return json.loads(urllib2.urlopen(otp_request_url).read())

def get_otp_suggested_trips(od_matrix,otp_url):
    trips_otp_response = {}
    counter = 0
    for row in od_matrix.collect():
        id=long(row['user_trip_id'])
        start_time = row['o_base_datetime'].split(' ')[1]
        trip_plan = get_otp_itineraries(otp_url,row['o_shape_lat'], row['o_shape_lon'], row['shapeLat'], row['shapeLon'],row['date'],start_time)
        trips_otp_response[id] = trip_plan
        counter+=1

    return trips_otp_response

def get_otp_scheduled_trips(od_matrix,otp_url):
    trips_otp_response = {}
    counter = 0
    for row in od_matrix.collect():
        id=long(row['user_trip_id'])
        start_time = row['o_base_datetime'].split(' ')[1]
        trip_plan = get_executed_trip_schedule(otp_url,row['o_shape_lat'], row['o_shape_lon'], row['shapeLat'], row['shapeLon'],
                                               row['date'],start_time,row['route'],row['o_stop_id'])
        trips_otp_response[id] = trip_plan
        counter+=1

    return trips_otp_response

def extract_otp_trips_legs(otp_trips):
    trips_legs = []

    for trip in otp_trips.keys():
        if 'plan' in otp_trips[trip]:
            itinerary_id = 1
            for itinerary in otp_trips[trip]['plan']['itineraries']:
                date = otp_trips[trip]['plan']['date']/1000
                leg_id = 1
                for leg in itinerary['legs']:
                    route = leg['route'] if leg['route'] != '' else None
                    fromStopId = leg['from']['stopId'].split(':')[1] if leg['mode'] == 'BUS' else None
                    toStopId = leg['to']['stopId'].split(':')[1] if leg['mode'] == 'BUS' else None
                    start_time = long(leg['startTime'])/1000
                    end_time = long(leg['endTime'])/1000
                    duration = (end_time - start_time)/60
                    trips_legs.append((date,trip,itinerary_id,leg_id,start_time,end_time,leg['mode'],route,fromStopId,toStopId, duration))
                    leg_id += 1
                itinerary_id += 1
    return trips_legs

def prepare_otp_legs_df(otp_legs_list):
    labels=['date','user_trip_id','itinerary_id','leg_id','otp_start_time','otp_end_time','mode','route','from_stop_id','to_stop_id','otp_duration_mins']
    otp_legs_df = sqlContext.createDataFrame(otp_legs_list, labels) \
                        .withColumn('date',F.from_unixtime(F.col('date'),'yyyy-MM-dd')) \
                        .withColumn('otp_duration_mins',((F.col('otp_end_time') - F.col('otp_start_time'))/60)) \
                        .withColumn('otp_start_time',F.from_unixtime(F.col('otp_start_time'),'yyyy-MM-dd HH:mm:ss').astype('timestamp')) \
                        .withColumn('otp_end_time',F.from_unixtime(F.col('otp_end_time'),'yyyy-MM-dd HH:mm:ss').astype('timestamp')) \
                        .withColumn('route', F.col('route').astype('integer')) \
                        .withColumn('from_stop_id', F.col('from_stop_id').astype('integer')) \
                        .withColumn('to_stop_id', F.col('to_stop_id').astype('integer')) \
                        .orderBy(['date','user_trip_id','itinerary_id','otp_start_time'])

    return otp_legs_df

# %% [markdown]
# #### Analysis Functions

# %%
def advance_od_matrix_start_time(od_matrix,extra_seconds):
    return od_matrix.withColumn('o_datetime', F.concat(F.col('date'), F.lit(' '), F.col('o_timestamp'))) \
                    .withColumn('d_datetime', F.concat(F.col('date'), F.lit(' '), F.col('timestamp'))) \
                    .withColumn('executed_duration', (F.unix_timestamp('d_datetime') - F.unix_timestamp('o_datetime'))/60) \
                    .withColumn('o_base_datetime', F.from_unixtime(F.unix_timestamp(F.col('o_datetime'),'yyyy-MM-dd HH:mm:ss') - extra_seconds, 'yyyy-MM-dd HH:mm:ss')) \

def get_df_stats(df,filtered_df,df_label,filtered_df_label):
    df_size = df.count()
    filtered_df_size = filtered_df.count()
    print "Total", df_label,":", df_size
    print "Total", filtered_df_label, ":", filtered_df_size, "(", 100*(filtered_df_size/float(df_size)), "%)"

def get_filtered_df_stats(filtered_df,full_df_size,filtered_df_label,full_df_label):
    filtered_df_size = filtered_df.count()
    print filtered_df_label, "in Total", full_df_label, ":", filtered_df_size, "(", 100*(filtered_df_size/float(full_df_size)), "%)"

def clean_buste_data(buste_data):
    return buste_data.select(["date","route","busCode","tripNum","stopPointId","timestamp"]) \
        .na.drop(subset=["date","route","busCode","tripNum","stopPointId","timestamp"]) \
        .dropDuplicates(['date','route','busCode','tripNum','stopPointId']) \
        .withColumn('route',F.col('route').astype('float')) \
        .withColumn('date',F.from_unixtime(F.col('date'),'yyyy-MM-dd')) \
        .withColumn('timestamp',F.from_unixtime(F.unix_timestamp(F.concat(F.col('date'),F.lit(' '),F.col('timestamp')), 'yyyy-MM-dd HH:mm:ss')))

def find_otp_bus_legs_actual_start_time(otp_legs_df,clean_bus_trips_df):
    w = Window.partitionBy(['date','user_trip_id','itinerary_id','route','from_stop_id']).orderBy(['timediff'])
    return otp_legs_df \
        .withColumn('stopPointId', F.col('from_stop_id')) \
        .join(clean_bus_trips_df, ['date','route','stopPointId'], how='inner') \
        .na.drop(subset=['timestamp']) \
        .withColumn('timediff',F.abs(F.unix_timestamp(F.col('timestamp')) - F.unix_timestamp(F.col('otp_start_time')))) \
        .drop('otp_duration') \
        .withColumn('rn', F.row_number().over(w)) \
        .where(F.col('rn') == 1) \
        .select(['date','user_trip_id','itinerary_id','leg_id','route','busCode','tripNum','from_stop_id','otp_start_time','timestamp','to_stop_id','otp_end_time']) \
        .withColumnRenamed('timestamp','from_timestamp')

def find_otp_bus_legs_actual_end_time(otp_legs_st,clean_bus_trips):
    return otp_legs_st \
                .withColumnRenamed('to_stop_id','stopPointId') \
                .join(clean_bus_trips, ['date','route','busCode','tripNum','stopPointId'], how='inner') \
                .na.drop(subset=['timestamp']) \
                .withColumn('timediff',F.abs(F.unix_timestamp(F.col('timestamp')) - F.unix_timestamp(F.col('otp_end_time')))) \
                .withColumnRenamed('timestamp', 'to_timestamp') \
                .withColumnRenamed('stopPointId','to_stop_id') \
                .orderBy(['date','route','stopPointId','timediff'])

def clean_otp_legs_actual_time_df(otp_legs_st_end_df):
    return otp_legs_start_end \
                .select(['date','user_trip_id','itinerary_id','leg_id','route','busCode','tripNum','from_stop_id','from_timestamp','to_stop_id','to_timestamp']) \
                .withColumn('actual_duration_mins', (F.unix_timestamp(F.col('to_timestamp')) - F.unix_timestamp(F.col('from_timestamp')))/60) \
                .orderBy(['date','user_trip_id','itinerary_id','leg_id']) \
                .filter('actual_duration_mins > 0')

def combine_otp_suggestions_with_bus_legs_actual_time(otp_suggestions,bus_legs_actual_time):
    return otp_legs_df \
                .join(clean_otp_legs_actual_time, on=['date','user_trip_id','itinerary_id','leg_id', 'route', 'from_stop_id','to_stop_id'], how='left') \
                .withColumn('considered_duration_mins', F.when(F.col('mode') == F.lit('BUS'), F.col('actual_duration_mins')).otherwise(F.col('otp_duration_mins'))) \
                .withColumn('considered_start_time', F.when(F.col('mode') == F.lit('BUS'), F.col('from_timestamp')).otherwise(F.col('otp_start_time')))

def select_itineraries_fully_identified(otp_itineraries_legs):
    itineraries_not_fully_identified = otp_itineraries_legs \
                                        .filter((otp_itineraries_legs.mode == 'BUS') & (otp_itineraries_legs.busCode.isNull())) \
                                        .select(['date','user_trip_id','itinerary_id']).distinct()
    itineraries_fully_identified = otp_itineraries_legs.select(['date','user_trip_id','itinerary_id']).subtract(itineraries_not_fully_identified)
    return otp_itineraries_legs.join(itineraries_fully_identified, on=['date','user_trip_id','itinerary_id'], how='inner')

def filter_itineraries_without_bus_legs(otp_itineraries_legs):
    itineraries_with_bus_legs = otp_itineraries_legs \
                                    .filter((otp_itineraries_legs.mode == 'BUS')) \
                                    .select(['date','user_trip_id','itinerary_id']).distinct()
    return otp_itineraries_legs.join(itineraries_with_bus_legs, on=['date','user_trip_id','itinerary_id'], how='inner')

# %% [markdown]
# ### Main Code

# %% [markdown]
# #### Reading Input Variables

# %%
initial_date = datetime.strptime('2017-07-01', '%Y-%m-%d')
final_date = datetime.strptime('2017-07-01', '%Y-%m-%d')
od_matrix_folderpath = '/local/tarciso/masters/data/bus_trips/test/single-day-test/2017_07_01/od/trips_od/'
buste_data_folderpath = '/local/tarciso/masters/data/bus_trips/test/single-day-test/2017_07_01/buste/'
otp_server_url = 'http://150.165.85.4:10402/otp/'
results_folderpath = '/local/tarciso/masters/data/bus_trips/test/single-day-test/2017_07_01'

# %% [markdown]
# #### Settting Up Environment

# %%
#Get Spark Session
spark  = SparkSession.builder.getOrCreate()
spark.conf.set('spark.sql.crossJoin.enabled', 'true')

sc = spark.sparkContext
sc.setLogLevel("ERROR")
sqlContext = pyspark.SQLContext(sc)

# %%
sc._conf.getAll()
# Out:
# [(u'spark.driver.port', u'50146'),
#  (u'hive.metastore.warehouse.dir',
#   u'file:/local/tarciso/workspace/trips-optimality-exp/spark-warehouse/'),
#  (u'spark.driver.host', u'10.30.0.113'),
#  (u'spark.driver.memory', u'4g'),
#  (u'spark.rdd.compress', u'True'),
#  (u'spark.serializer.objectStreamReset', u'100'),
#  (u'spark.master', u'local[*]'),
#  (u'spark.executor.id', u'driver'),
#  (u'spark.submit.deployMode', u'client'),
#  (u'spark.app.id', u'local-1522184092296'),
#  (u'spark.app.name', u'PySparkShell')]

# %% [markdown]
# #### Reading OD Matrix

# %%
print "Got Spark Context"

print "Reading OD-Matrix Data..."
od_matrix_day_folderpath = od_matrix_folderpath + '/' + initial_date.strftime('%Y_%m_%d') + '_od'
od_matrix = read_hdfs_folder(sqlContext, od_matrix_day_folderpath)

print "Fixing OD Matrix dates due to bug on date saving on cluster..."
SECONDS_OFFSET = 10800
od_matrix = od_matrix \
                .withColumn('date',F.col('date') + SECONDS_OFFSET) \
                .withColumn('o_date',F.col('o_date') + SECONDS_OFFSET) \
                .withColumn('next_o_date',F.col('next_o_date') + SECONDS_OFFSET) \
                .withColumn('date', F.from_unixtime(F.col('date'), 'yyyy-MM-dd')) \
                .withColumnRenamed('o_boarding_id','user_trip_id')
        
print "Preprocessing Data..."
od_matrix = advance_od_matrix_start_time(od_matrix,120)
# Out:
# Got Spark Context
# Reading OD-Matrix Data...
# Fixing OD Matrix dates due to bug on date saving on cluster...
# Preprocessing Data...

# %%
od_matrix.printSchema()
# Out:
# root
#  |-- route: integer (nullable = true)
#  |-- tripNum: integer (nullable = true)
#  |-- shapeId: integer (nullable = true)
#  |-- shapeSequence: integer (nullable = true)
#  |-- shapeLat: double (nullable = true)
#  |-- shapeLon: double (nullable = true)
#  |-- distanceTraveledShape: double (nullable = true)
#  |-- busCode: string (nullable = true)
#  |-- gpsPointId: string (nullable = true)
#  |-- gpsLat: double (nullable = true)
#  |-- gpsLon: double (nullable = true)
#  |-- distanceToShapePoint: double (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- stopPointId: integer (nullable = true)
#  |-- problem: string (nullable = true)
#  |-- birthdate: string (nullable = true)
#  |-- cardTimestamp: string (nullable = true)
#  |-- lineName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- o_route: integer (nullable = true)
#  |-- o_bus_code: string (nullable = true)
#  |-- o_date: integer (nullable = true)
#  |-- o_tripNum: integer (nullable = true)
#  |-- o_timestamp: string (nullable = true)
#  |-- o_shape_id: integer (nullable = true)
#  |-- o_shape_seq: integer (nullable = true)
#  |-- o_shape_lat: double (nullable = true)
#  |-- o_shape_lon: double (nullable = true)
#  |-- o_stop_id: integer (nullable = true)
#  |-- user_trip_id: long (nullable = true)
#  |-- cardNum: integer (nullable = true)
#  |-- next_o_route: integer (nullable = true)
#  |-- next_o_bus_code: string (nullable = true)
#  |-- next_o_date: integer (nullable = true)
#  |-- next_o_tripNum: integer (nullable = true)
#  |-- next_o_timestamp: string (nullable = true)
#  |-- next_o_shape_id: integer (nullable = true)
#  |-- next_o_shape_seq: integer (nullable = true)
#  |-- next_o_shape_lat: double (nullable = true)
#  |-- next_o_shape_lon: double (nullable = true)
#  |-- next_o_stop_id: integer (nullable = true)
#  |-- next_o_boarding_id: long (nullable = true)
#  |-- o_unixtimestamp: integer (nullable = true)
#  |-- next_o_unixtimestamp: integer (nullable = true)
#  |-- leg_duration: double (nullable = true)
#  |-- dist: double (nullable = true)
#  |-- rn: integer (nullable = true)
#  |-- o_datetime: string (nullable = true)
#  |-- d_datetime: string (nullable = true)
#  |-- executed_duration: double (nullable = true)
#  |-- o_base_datetime: string (nullable = true)

# %%
printdf(od_matrix.select(['timestamp','birthdate','cardTimestamp','date','o_date','o_timestamp','next_o_date','next_o_timestamp','o_unixtimestamp','next_o_unixtimestamp','o_base_datetime']))
# Out:
#   timestamp birthdate cardTimestamp        date      o_date o_timestamp  \
# 0  21:47:02  31/07/77      21:50:20  2017-07-01  1498878000    21:42:00
# 1  13:12:13      None          None  2017-07-01  1498878000    05:41:47
# 2  15:20:19      None          None  2017-07-01  1498878000    14:52:03
# 3  13:58:28  02/07/90      13:59:08  2017-07-01  1498878000    13:46:52
# 4  20:08:25      None          None  2017-07-01  1498878000    19:03:53
# 5  06:36:28      None          None  2017-07-01  1498878000    05:38:22
# 6  06:11:39      None          None  2017-07-01  1498878000    05:51:53
# 7  19:25:51      None          None  2017-07-01  1498878000    19:03:41
# 8  20:11:47  13/11/61      20:12:31  2017-07-01  1498878000    19:47:50
# 9  09:40:32      None          None  2017-07-01  1498878000    09:32:49
#
#    next_o_date next_o_timestamp  o_unixtimestamp  next_o_unixtimestamp  \
# 0   1498878000         12:36:07            78120                 45367
# 1   1498878000         15:13:38            20507                 54818
# 2   1498878000         07:24:50            53523                 26690
# 3   1498878000         12:59:09            49612                 46749
# 4   1498878000         18:21:32            68633                 66092
# 5   1498878000         12:59:23            20302                 46763
# 6   1498878000         11:48:49            21113                 42529
# 7   1498878000         12:46:39            68621                 45999
# 8   1498878000         13:26:32            71270                 48392
# 9   1498878000         06:01:21            34369                 21681
#
#        o_base_datetime
# 0  2017-07-01 21:40:00
# 1  2017-07-01 05:39:47
# 2  2017-07-01 14:50:03
# 3  2017-07-01 13:44:52
# 4  2017-07-01 19:01:53
# 5  2017-07-01 05:36:22
# 6  2017-07-01 05:49:53
# 7  2017-07-01 19:01:41
# 8  2017-07-01 19:45:50
# 9  2017-07-01 09:30:49

# %%
raw_od_matrix = od_matrix

# %%
od_matrix = raw_od_matrix.limit(50)

# %%
od_matrix.count()
# Out:
# 50

# %% [markdown]
# #### Getting OTP suggested itineraries

# %%
print "Getting OTP suggested itineraries..."
otp_suggestions = get_otp_suggested_trips(od_matrix,otp_server_url)

print "Extracting OTP Legs info..."
otp_legs_df = prepare_otp_legs_df(extract_otp_trips_legs(otp_suggestions))
#otp_legs_df.write.csv(path=results_folderpath+'/trip_plans',header=True, mode='append')

otp_suggestions = None
# Out:
# Getting OTP suggested itineraries...
# Extracting OTP Legs info...

# %%
printdf(otp_legs_df)
# Out:
#          date  user_trip_id  itinerary_id  leg_id      otp_start_time  \
# 0  2017-07-01   34359738511             1       1 2017-07-01 05:46:59
# 1  2017-07-01   34359738511             1       2 2017-07-01 06:07:23
# 2  2017-07-01   34359738511             1       3 2017-07-01 06:15:01
# 3  2017-07-01   34359738511             2       1 2017-07-01 06:06:59
# 4  2017-07-01   34359738511             2       2 2017-07-01 06:27:23
# 5  2017-07-01   34359738511             2       3 2017-07-01 06:35:01
# 6  2017-07-01   34359738511             3       1 2017-07-01 06:16:59
# 7  2017-07-01   34359738511             3       2 2017-07-01 06:37:23
# 8  2017-07-01   34359738511             3       3 2017-07-01 06:45:01
# 9  2017-07-01   68719476815             1       1 2017-07-01 06:58:58
#
#          otp_end_time  mode  route  from_stop_id  to_stop_id  \
# 0 2017-07-01 06:07:22  WALK    NaN           NaN         NaN
# 1 2017-07-01 06:15:00   BUS  500.0       25471.0     27560.0
# 2 2017-07-01 06:18:39  WALK    NaN           NaN         NaN
# 3 2017-07-01 06:27:22  WALK    NaN           NaN         NaN
# 4 2017-07-01 06:35:00   BUS  500.0       25471.0     27560.0
# 5 2017-07-01 06:38:39  WALK    NaN           NaN         NaN
# 6 2017-07-01 06:37:22  WALK    NaN           NaN         NaN
# 7 2017-07-01 06:45:00   BUS  500.0       25471.0     27560.0
# 8 2017-07-01 06:48:39  WALK    NaN           NaN         NaN
# 9 2017-07-01 07:21:41  WALK    NaN           NaN         NaN
#
#    otp_duration_mins
# 0          20.383333
# 1           7.616667
# 2           3.633333
# 3          20.383333
# 4           7.616667
# 5           3.633333
# 6          20.383333
# 7           7.616667
# 8           3.633333
# 9          22.716667

# %% [markdown]
# #### Gathering schedule info for executed trips

# %%
print "Getting OTP schedule info for executed trips..."
executed_trips_schedule = get_otp_scheduled_trips(od_matrix,otp_server_url)
# Out:
# Getting OTP schedule info for executed trips...

# %%
executed_trips_schedule
# Out:
# {17179869310L: {u'debugOutput': {u'pathCalculationTime': 25,
#    u'pathTimes': [],
#    u'precalculationTime': 13,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 38},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4230038133,-49.2413612816',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_21',
#    u'startTransitStopId': u'1_29097',
#    u'time': u'12:59:31',
#    u'toPlace': u'-25.3975151075,-49.250717905'}},
#  17179869337L: {u'debugOutput': {u'pathCalculationTime': 73,
#    u'pathTimes': [],
#    u'precalculationTime': 27,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 100},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4281230769,-49.2718964723',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_176',
#    u'startTransitStopId': u'1_28556',
#    u'time': u'15:52:39',
#    u'toPlace': u'-25.3986748562,-49.2736309239'}},
#  34359738511L: {u'debugOutput': {u'pathCalculationTime': 24,
#    u'pathTimes': [24],
#    u'precalculationTime': 44,
#    u'renderingTime': 1,
#    u'timedOut': False,
#    u'totalTime': 69},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'plan': {u'date': 1498898387000,
#    u'from': {u'lat': -25.4604272304,
#     u'lon': -49.2495334715,
#     u'name': u'Origin',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'},
#    u'itineraries': [{u'duration': 1900,
#      u'elevationGained': 0.0,
#      u'elevationLost': 0.0,
#      u'endTime': 1498900719000,
#      u'legs': [{u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 1550.7310000000004,
#        u'duration': 1223.0,
#        u'endTime': 1498900042000,
#        u'from': {u'departure': 1498898819000,
#         u'lat': -25.4604272304,
#         u'lon': -49.2495334715,
#         u'name': u'Origin',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 46,
#         u'points': u'zvkzCd`rkHSI_@Ma@WY_@OKKBYXCNSdAG\\Ov@Ov@Kb@M`@MPmDtA}@^f@lBa@RmBnCSJJXqA`Bq@`AEFwBzCI`@ERER@H?JAJEFAD?TFVL\\vGfTnAe@t@YxAk@|Am@@NLTJE'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498898819000,
#        u'steps': [{u'absoluteDirection': u'NORTH',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 31.445999999999998,
#          u'elevation': [],
#          u'lat': -25.460452820723848,
#          u'lon': -49.24946110273864,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Rua Canal Bel\xe9m'},
#         {u'absoluteDirection': u'NORTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 54.566,
#          u'elevation': [],
#          u'lat': -25.460190500000003,
#          u'lon': -49.2493441,
#          u'relativeDirection': u'CONTINUE',
#          u'stayOn': False,
#          u'streetName': u'Rua Canal Bel\xe9m'},
#         {u'absoluteDirection': u'NORTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 71.604,
#          u'elevation': [],
#          u'lat': -25.4598149,
#          u'lon': -49.2490025,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Avenida Senador Salgado Filho'},
#         {u'absoluteDirection': u'WEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 74.649,
#          u'elevation': [],
#          u'lat': -25.4595069,
#          u'lon': -49.249586,
#          u'relativeDirection': u'CONTINUE',
#          u'stayOn': False,
#          u'streetName': u'Rua Imaculada Conceicao'},
#         {u'absoluteDirection': u'WEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 194.04000000000002,
#          u'elevation': [],
#          u'lat': -25.459300300000002,
#          u'lon': -49.250293400000004,
#          u'relativeDirection': u'CONTINUE',
#          u'stayOn': False,
#          u'streetName': u'Rua Imaculada Concei\xe7\xe3o'},
#         {u'absoluteDirection': u'WEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 59.27,
#          u'elevation': [],
#          u'lat': -25.457924000000002,
#          u'lon': -49.2513291,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Pedro de Toledo'},
#         {u'absoluteDirection': u'NORTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 128.938,
#          u'elevation': [],
#          u'lat': -25.458127800000003,
#          u'lon': -49.2518746,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Rua Professora Regina Celia Marinoni'},
#         {u'absoluteDirection': u'SOUTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 14.394,
#          u'elevation': [],
#          u'lat': -25.4573065,
#          u'lon': -49.252755500000006,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Thomas Edison'},
#         {u'absoluteDirection': u'NORTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 257.177,
#          u'elevation': [],
#          u'lat': -25.4573605,
#          u'lon': -49.2528858,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Rua Professora Regina Casagrande Marinoni'},
#         {u'absoluteDirection': u'WEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 23.0,
#          u'elevation': [],
#          u'exit': u'1',
#          u'lat': -25.455961400000003,
#          u'lon': -49.2548952,
#          u'relativeDirection': u'CIRCLE_CLOCKWISE',
#          u'stayOn': False,
#          u'streetName': u'Rua Professora Regina Casagrande Marinoni'},
#         {u'absoluteDirection': u'WEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 419.24,
#          u'elevation': [],
#          u'lat': -25.455931300000003,
#          u'lon': -49.2551063,
#          u'relativeDirection': u'SLIGHTLY_LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Jo\xe3o Parolin'},
#         {u'absoluteDirection': u'SOUTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 222.407,
#          u'elevation': [],
#          u'lat': -25.457437000000002,
#          u'lon': -49.2589179,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Avenida Marechal Floriano Peixoto'}],
#        u'to': {u'arrival': 1498900042000,
#         u'departure': 1498900043000,
#         u'lat': -25.459149308599,
#         u'lon': -49.258267608183,
#         u'name': u'Esta\xe7\xe3o Tubo TRE',
#         u'stopCode': u'108077',
#         u'stopId': u'1:25471',
#         u'stopIndex': 3,
#         u'stopSequence': 4,
#         u'vertexType': u'TRANSIT'},
#        u'transitLeg': False},
#       {u'agencyId': u'1',
#        u'agencyName': u'URBS',
#        u'agencyTimeZoneOffset': -10800000,
#        u'agencyUrl': u'http://www.urbs.curitiba.pr.gov.br',
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 3072.8273830981298,
#        u'duration': 457.0,
#        u'endTime': 1498900500000,
#        u'from': {u'arrival': 1498900042000,
#         u'departure': 1498900043000,
#         u'lat': -25.459149308599,
#         u'lon': -49.258267608183,
#         u'name': u'Esta\xe7\xe3o Tubo TRE',
#         u'stopCode': u'108077',
#         u'stopId': u'1:25471',
#         u'stopIndex': 3,
#         u'stopSequence': 4,
#         u'vertexType': u'TRANSIT'},
#        u'headsign': u'Pra\xe7a Carlos Gomes (S\xe1bado)',
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 128,
#         u'points': u'pnkzCrvskHODi@P{@d@YLo@VeA^eAb@eA^i@R_@N]N_@NeA`@}@\\]Hc@N}@\\_@PWLYN_@LYLUJYJSFWJYJWJ[L]Lm@Ti@Ru@T_@Lc@PYJk@Tc@Vg@R[Lk@T}@Z[Lw@VYHQHQFYJu@Xq@Vo@Vo@Tq@Vm@Ns@Xm@Tk@Vc@Vg@RcBn@q@VYNUFm@Vo@Vs@Xc@Nc@P_A^y@Te@Ne@Rk@V}@`@oBv@k@RSHWL]Pu@^[NWJ]L]LWJa@P_@Ni@P_@PYJg@RaA^}Aj@e@Pc@Pg@RSHaA^e@NC@e@RaA\\y@sC]kAc@R]Lq@Xk@Ta@P_@La@NUHo@Xo@Vw@\\m@T_A^y@^_Bn@m@Vq@Vi@Ve@NNj@J\\FVXz@'},
#        u'mode': u'BUS',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'500',
#        u'routeColor': u'1E16B5',
#        u'routeId': u'1:818',
#        u'routeLongName': u'LIGEIRAO BOQUEIRAO',
#        u'routeShortName': u'500',
#        u'routeTextColor': u'ffffff',
#        u'routeType': 3,
#        u'serviceDate': u'20170701',
#        u'startTime': 1498900043000,
#        u'steps': [],
#        u'to': {u'arrival': 1498900500000,
#         u'departure': 1498900501000,
#         u'lat': -25.433741254877,
#         u'lon': -49.270291657395,
#         u'name': u'Esta\xe7\xe3o Tubo Pra\xe7a Carlos Gomes',
#         u'stopCode': u'108065',
#         u'stopId': u'1:27560',
#         u'stopIndex': 5,
#         u'stopSequence': 6,
#         u'vertexType': u'TRANSIT'},
#        u'transitLeg': True,
#        u'tripId': u'1:3878719'},
#       {u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 274.308,
#        u'duration': 218.0,
#        u'endTime': 1498900719000,
#        u'from': {u'arrival': 1498900500000,
#         u'departure': 1498900501000,
#         u'lat': -25.433741254877,
#         u'lon': -49.270291657395,
#         u'name': u'Esta\xe7\xe3o Tubo Pra\xe7a Carlos Gomes',
#         u'stopCode': u'108065',
#         u'stopId': u'1:27560',
#         u'stopIndex': 5,
#         u'stopSequence': 6,
#         u'vertexType': u'TRANSIT'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 11,
#         u'points': u'dpfzCfbvkHRr@BH~@|Cx@`CHCPGp@WXKVIDA'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498900501000,
#        u'steps': [{u'absoluteDirection': u'SOUTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 193.66699999999997,
#          u'elevation': [],
#          u'lat': -25.433786911598403,
#          u'lon': -49.27027035230426,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Rua Pedro Ivo'},
#         {u'absoluteDirection': u'SOUTH',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 80.64099999999999,
#          u'elevation': [],
#          u'lat': -25.4345131,
#          u'lon': -49.2720229,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Desembargador Westphalen'}],
#        u'to': {u'arrival': 1498900719000,
#         u'lat': -25.4351969671,
#         u'lon': -49.2717527761,
#         u'name': u'Destination',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'transitLeg': False}],
#      u'startTime': 1498898819000,
#      u'tooSloped': False,
#      u'transfers': 0,
#      u'transitTime': 457,
#      u'waitingTime': 2,
#      u'walkDistance': 1825.3946390862695,
#      u'walkLimitExceeded': False,
#      u'walkTime': 1441}],
#    u'to': {u'lat': -25.4351969671,
#     u'lon': -49.2717527761,
#     u'name': u'Destination',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'}},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4604272304,-49.2495334715',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_475',
#    u'startTransitStopId': u'1_33479',
#    u'time': u'05:39:47',
#    u'toPlace': u'-25.4351969671,-49.2717527761'}},
#  42949672972L: {u'debugOutput': {u'pathCalculationTime': 25,
#    u'pathTimes': [],
#    u'precalculationTime': 11,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 36},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.5365607469,-49.3014740186',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_650',
#    u'startTransitStopId': u'1_32036',
#    u'time': u'20:33:27',
#    u'toPlace': u'-25.5619720911,-49.3392846069'}},
#  68719476815L: {u'debugOutput': {u'pathCalculationTime': 42,
#    u'pathTimes': [42],
#    u'precalculationTime': 21,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 63},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'plan': {u'date': 1498903138000,
#    u'from': {u'lat': -25.4408650604,
#     u'lon': -49.2714569042,
#     u'name': u'Origin',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'},
#    u'itineraries': [{u'duration': 1363,
#      u'elevationGained': 0.0,
#      u'elevationLost': 0.0,
#      u'endTime': 1498904501000,
#      u'legs': [{u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 1783.3010000000002,
#        u'duration': 1363.0,
#        u'endTime': 1498904501000,
#        u'from': {u'departure': 1498903138000,
#         u'lat': -25.4408650604,
#         u'lon': -49.2714569042,
#         u'name': u'Origin',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 23,
#         u'points': u'l|gzCtivkHn@U^MhG{BZKxCmAlCeAnGgCv@YpEcBxEgBp@WlAc@xCeAnE}AjC}@dFkBvBu@|Bw@pBtBfDlDTVZ^'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498903138000,
#        u'steps': [{u'absoluteDirection': u'SOUTH',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 1529.382,
#          u'elevation': [],
#          u'lat': -25.440867994787304,
#          u'lon': -49.27146482136429,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Rua Alferes Poli'},
#         {u'absoluteDirection': u'SOUTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 253.919,
#          u'elevation': [],
#          u'lat': -25.453529300000003,
#          u'lon': -49.265519600000005,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Avenida Presidente Kennedy'}],
#        u'to': {u'arrival': 1498904501000,
#         u'lat': -25.4551674562,
#         u'lon': -49.2672796494,
#         u'name': u'Destination',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'transitLeg': False}],
#      u'startTime': 1498903138000,
#      u'tooSloped': False,
#      u'transfers': 0,
#      u'transitTime': 0,
#      u'waitingTime': 0,
#      u'walkDistance': 1783.3306992471623,
#      u'walkLimitExceeded': False,
#      u'walkTime': 1363}],
#    u'to': {u'lat': -25.4551674562,
#     u'lon': -49.2672796494,
#     u'name': u'Destination',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'}},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4408650604,-49.2714569042',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_663',
#    u'startTransitStopId': u'1_26631',
#    u'time': u'06:58:58',
#    u'toPlace': u'-25.4551674562,-49.2672796494'}},
#  85899345938L: {u'debugOutput': {u'pathCalculationTime': 12,
#    u'pathTimes': [],
#    u'precalculationTime': 8,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 20},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.572530446,-49.3377672151',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_619',
#    u'startTransitStopId': u'1_36280',
#    u'time': u'05:49:53',
#    u'toPlace': u'-25.5380803213,-49.3138996399'}},
#  111669149726L: {u'debugOutput': {u'pathCalculationTime': 18,
#    u'pathTimes': [18],
#    u'precalculationTime': 16,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 34},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'plan': {u'date': 1498924995000,
#    u'from': {u'lat': -25.5263987826,
#     u'lon': -49.252941479,
#     u'name': u'Origin',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'},
#    u'itineraries': [{u'duration': 1488,
#      u'elevationGained': 0.0,
#      u'elevationLost': 0.0,
#      u'endTime': 1498926483000,
#      u'legs': [{u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 1896.4569999999997,
#        u'duration': 1488.0,
#        u'endTime': 1498926483000,
#        u'from': {u'departure': 1498924995000,
#         u'lat': -25.5263987826,
#         u'lon': -49.252941479,
#         u'name': u'Origin',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 69,
#         u'points': u'|rxzCzurkHJUn@gB^_@LCDAHIFO?MCQ?y@Z{@Nc@^aAJYL[Vi@f@e@RQ`@i@BC\\i@xAiCHQN[LYTi@Vm@Z_@TWNS~@gARYJQ`@w@DGRm@Lk@d@oBp@kCRw@FWVaAJ]|AGd@G@A~AQlA[~@g@rCw@~@W??b@Mh@Wd@WhB}@XO`@MbA[dA]p@KREx@Mp@GlAKfCQn@CDA'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498924995000,
#        u'steps': [{u'absoluteDirection': u'SOUTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 139.38299999999998,
#          u'elevation': [],
#          u'exit': u'3',
#          u'lat': -25.526389756310422,
#          u'lon': -49.252936249982426,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': True,
#          u'streetName': u'Rua Francisco Derosso'},
#         {u'absoluteDirection': u'EAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 908.234,
#          u'elevation': [],
#          u'lat': -25.5270189,
#          u'lon': -49.251826900000005,
#          u'relativeDirection': u'CONTINUE',
#          u'stayOn': False,
#          u'streetName': u'Rua Francisco Derosso'},
#         {u'absoluteDirection': u'SOUTH',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 848.84,
#          u'elevation': [],
#          u'lat': -25.5311002,
#          u'lon': -49.2441607,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Rua Eduardo Pinto da Rocha'}],
#        u'to': {u'arrival': 1498926483000,
#         u'lat': -25.5383532493,
#         u'lon': -49.241800943,
#         u'name': u'Destination',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'transitLeg': False}],
#      u'startTime': 1498924995000,
#      u'tooSloped': False,
#      u'transfers': 0,
#      u'transitTime': 0,
#      u'waitingTime': 0,
#      u'walkDistance': 1896.6043684162971,
#      u'walkLimitExceeded': False,
#      u'walkTime': 1488}],
#    u'to': {u'lat': -25.5383532493,
#     u'lon': -49.241800943,
#     u'name': u'Destination',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'}},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.5263987826,-49.252941479',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_629',
#    u'startTransitStopId': u'1_29839',
#    u'time': u'13:03:15',
#    u'toPlace': u'-25.5383532493,-49.241800943'}},
#  120259084404L: {u'debugOutput': {u'pathCalculationTime': 17,
#    u'pathTimes': [],
#    u'precalculationTime': 12,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 29},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4874477052,-49.3486748321',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_658',
#    u'startTransitStopId': u'1_35869',
#    u'time': u'19:01:58',
#    u'toPlace': u'-25.4916683527,-49.2973396798'}},
#  128849018906L: {u'debugOutput': {u'pathCalculationTime': 40,
#    u'pathTimes': [40],
#    u'precalculationTime': 24,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 64},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'plan': {u'date': 1498928825000,
#    u'from': {u'lat': -25.4455616603,
#     u'lon': -49.2692233924,
#     u'name': u'Origin',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'},
#    u'itineraries': [{u'duration': 1716,
#      u'elevationGained': 0.0,
#      u'elevationLost': 0.0,
#      u'endTime': 1498931137000,
#      u'legs': [{u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 1044.942,
#        u'duration': 811.0,
#        u'endTime': 1498930232000,
#        u'from': {u'departure': 1498929421000,
#         u'lat': -25.4455616603,
#         u'lon': -49.2692233924,
#         u'name': u'Origin',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 19,
#         u'points': u'|yhzCr{ukHAEoGfCmCdAyClA[JiGzBgAwDmAiEs@cCW}@_@Q]oAKa@AIcC|@IDk@RA@'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498929421000,
#        u'steps': [{u'absoluteDirection': u'NORTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 3.062,
#          u'elevation': [],
#          u'lat': -25.44558519855437,
#          u'lon': -49.269211915454804,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Rua Engenheiros Rebou\xe7as'},
#         {u'absoluteDirection': u'NORTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 523.6220000000001,
#          u'elevation': [],
#          u'lat': -25.4455741,
#          u'lon': -49.269184,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Alferes Poli'},
#         {u'absoluteDirection': u'NORTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 317.711,
#          u'elevation': [],
#          u'lat': -25.4412659,
#          u'lon': -49.2712883,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Avenida Silva Jardim'},
#         {u'absoluteDirection': u'NORTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 86.592,
#          u'elevation': [],
#          u'lat': -25.440132600000002,
#          u'lon': -49.2683838,
#          u'relativeDirection': u'SLIGHTLY_LEFT',
#          u'stayOn': False,
#          u'streetName': u'Avenida Silva Jardim'},
#         {u'absoluteDirection': u'NORTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 113.95499999999998,
#          u'elevation': [],
#          u'lat': -25.439752600000002,
#          u'lon': -49.267676200000004,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Avenida Marechal Floriano Peixoto'}],
#        u'to': {u'arrival': 1498930232000,
#         u'departure': 1498930233000,
#         u'lat': -25.438807575773,
#         u'lon': -49.268115338581,
#         u'name': u'Esta\xe7\xe3o Tubo UTFPR - Desembarque',
#         u'stopCode': u'108214',
#         u'stopId': u'1:25515',
#         u'stopIndex': 4,
#         u'stopSequence': 5,
#         u'vertexType': u'TRANSIT'},
#        u'transitLeg': False},
#       {u'agencyId': u'1',
#        u'agencyName': u'URBS',
#        u'agencyTimeZoneOffset': -10800000,
#        u'agencyUrl': u'http://www.urbs.curitiba.pr.gov.br',
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 604.253297131421,
#        u'duration': 87.0,
#        u'endTime': 1498930320000,
#        u'from': {u'arrival': 1498930232000,
#         u'departure': 1498930233000,
#         u'lat': -25.438807575773,
#         u'lon': -49.268115338581,
#         u'name': u'Esta\xe7\xe3o Tubo UTFPR - Desembarque',
#         u'stopCode': u'108214',
#         u'stopId': u'1:25515',
#         u'stopIndex': 4,
#         u'stopSequence': 5,
#         u'vertexType': u'TRANSIT'},
#        u'headsign': u'Pra\xe7a Carlos Gomes (S\xe1bado)',
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 28,
#         u'points': u'rogzCztukHe@RaA\\y@sC]kAc@R]Lq@Xk@Ta@P_@La@NUHo@Xo@Vw@\\m@T_A^y@^_Bn@m@Vq@Vi@Ve@NNj@J\\FVXz@'},
#        u'mode': u'BUS',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'500',
#        u'routeColor': u'1E16B5',
#        u'routeId': u'1:818',
#        u'routeLongName': u'LIGEIRAO BOQUEIRAO',
#        u'routeShortName': u'500',
#        u'routeTextColor': u'ffffff',
#        u'routeType': 3,
#        u'serviceDate': u'20170701',
#        u'startTime': 1498930233000,
#        u'steps': [],
#        u'to': {u'arrival': 1498930320000,
#         u'departure': 1498930321000,
#         u'lat': -25.433741254877,
#         u'lon': -49.270291657395,
#         u'name': u'Esta\xe7\xe3o Tubo Pra\xe7a Carlos Gomes',
#         u'stopCode': u'108065',
#         u'stopId': u'1:27560',
#         u'stopIndex': 5,
#         u'stopSequence': 6,
#         u'vertexType': u'TRANSIT'},
#        u'transitLeg': True,
#        u'tripId': u'1:3878756'},
#       {u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 1036.1009999999999,
#        u'duration': 816.0,
#        u'endTime': 1498931137000,
#        u'from': {u'arrival': 1498930320000,
#         u'departure': 1498930321000,
#         u'lat': -25.433741254877,
#         u'lon': -49.270291657395,
#         u'name': u'Esta\xe7\xe3o Tubo Pra\xe7a Carlos Gomes',
#         u'stopCode': u'108065',
#         u'stopId': u'1:27560',
#         u'stopIndex': 5,
#         u'stopSequence': 6,
#         u'vertexType': u'TRANSIT'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 38,
#         u'points': u'dpfzCfbvkHRr@eDlAu@X]LUHQH}@\\C@sAf@SHa@Pe@PiCbAYFMAc@DEFIDUHWHk@TE@IJEJeAl@gCt@Hb@FXBf@It@IhADd@DXb@fB~@bENp@BP'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498930321000,
#        u'steps': [{u'absoluteDirection': u'SOUTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 28.773,
#          u'elevation': [],
#          u'lat': -25.433786911598403,
#          u'lon': -49.27027035230426,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Rua Pedro Ivo'},
#         {u'absoluteDirection': u'NORTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 406.557,
#          u'elevation': [],
#          u'lat': -25.433887400000003,
#          u'lon': -49.2705344,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Avenida Marechal Floriano Peixoto'},
#         {u'absoluteDirection': u'NORTH',
#          u'area': True,
#          u'bogusName': False,
#          u'distance': 14.87,
#          u'elevation': [],
#          u'lat': -25.430537400000002,
#          u'lon': -49.272156100000004,
#          u'relativeDirection': u'CONTINUE',
#          u'stayOn': False,
#          u'streetName': u'Pra\xe7a Jos\xe9 Borges de Macedo'},
#         {u'absoluteDirection': u'NORTH',
#          u'area': True,
#          u'bogusName': False,
#          u'distance': 8.616,
#          u'elevation': [],
#          u'lat': -25.4304081,
#          u'lon': -49.272193900000005,
#          u'relativeDirection': u'SLIGHTLY_RIGHT',
#          u'stayOn': True,
#          u'streetName': u'Pra\xe7a Jos\xe9 Borges de Macedo'},
#         {u'absoluteDirection': u'NORTH',
#          u'area': True,
#          u'bogusName': True,
#          u'distance': 19.728,
#          u'elevation': [],
#          u'lat': -25.430331300000002,
#          u'lon': -49.2721825,
#          u'relativeDirection': u'CONTINUE',
#          u'stayOn': False,
#          u'streetName': u'open area'},
#         {u'absoluteDirection': u'NORTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 84.67500000000001,
#          u'elevation': [],
#          u'lat': -25.430156,
#          u'lon': -49.272212800000005,
#          u'relativeDirection': u'SLIGHTLY_LEFT',
#          u'stayOn': False,
#          u'streetName': u'Pra\xe7a Tiradentes'},
#         {u'absoluteDirection': u'NORTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 125.45599999999999,
#          u'elevation': [],
#          u'lat': -25.4295189,
#          u'lon': -49.2726285,
#          u'relativeDirection': u'SLIGHTLY_RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Rua do Ros\xe1rio'},
#         {u'absoluteDirection': u'WEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 81.217,
#          u'elevation': [],
#          u'lat': -25.4284876,
#          u'lon': -49.2731216,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Travessa Nestor de Castro'},
#         {u'absoluteDirection': u'WEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 266.209,
#          u'elevation': [],
#          u'lat': -25.4285442,
#          u'lon': -49.2739088,
#          u'relativeDirection': u'CONTINUE',
#          u'stayOn': False,
#          u'streetName': u'Alameda Augusto Stellfeld'}],
#        u'to': {u'arrival': 1498931137000,
#         u'lat': -25.4291612633,
#         u'lon': -49.2764313537,
#         u'name': u'Destination',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'transitLeg': False}],
#      u'startTime': 1498929421000,
#      u'tooSloped': False,
#      u'transfers': 0,
#      u'transitTime': 87,
#      u'waitingTime': 2,
#      u'walkDistance': 2081.3230751789324,
#      u'walkLimitExceeded': False,
#      u'walkTime': 1627}],
#    u'to': {u'lat': -25.4291612633,
#     u'lon': -49.2764313537,
#     u'name': u'Destination',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'}},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4455616603,-49.2692233924',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_160',
#    u'startTransitStopId': u'1_26629',
#    u'time': u'14:07:05',
#    u'toPlace': u'-25.4291612633,-49.2764313537'}},
#  128849018984L: {u'debugOutput': {u'pathCalculationTime': 56,
#    u'pathTimes': [],
#    u'precalculationTime': 20,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 76},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4433948196,-49.2702677997',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_673',
#    u'startTransitStopId': u'1_26630',
#    u'time': u'13:59:56',
#    u'toPlace': u'-25.4890131697,-49.2968313044'}},
#  128849019050L: {u'debugOutput': {u'pathCalculationTime': 27,
#    u'pathTimes': [],
#    u'precalculationTime': 23,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 50},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4900315637,-49.2145458538',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_468',
#    u'startTransitStopId': u'1_31942',
#    u'time': u'06:26:32',
#    u'toPlace': u'-25.440210425,-49.2687047166'}},
#  146028888172L: {u'debugOutput': {u'pathCalculationTime': 4,
#    u'pathTimes': [4],
#    u'precalculationTime': 24,
#    u'renderingTime': 1,
#    u'timedOut': False,
#    u'totalTime': 29},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'plan': {u'date': 1498938573000,
#    u'from': {u'lat': -25.4392036083,
#     u'lon': -49.2798294196,
#     u'name': u'Origin',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'},
#    u'itineraries': [{u'duration': 512,
#      u'elevationGained': 0.0,
#      u'elevationLost': 0.0,
#      u'endTime': 1498939085000,
#      u'legs': [{u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 653.7950000000001,
#        u'duration': 512.0,
#        u'endTime': 1498939085000,
#        u'from': {u'departure': 1498938573000,
#         u'lat': -25.4392036083,
#         u'lon': -49.2798294196,
#         u'name': u'Origin',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 13,
#         u'points': u'~qgzC`~wkHeBgBj@s@Im@mA_E_AgDc@aBiAwDGWaAeD]w@q@V?@'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498938573000,
#        u'steps': [{u'absoluteDirection': u'NORTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 76.033,
#          u'elevation': [],
#          u'lat': -25.439194121238312,
#          u'lon': -49.27984088355928,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Rua Emiliano Perneta'},
#         {u'absoluteDirection': u'SOUTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 35.901,
#          u'elevation': [],
#          u'lat': -25.43869,
#          u'lon': -49.2793293,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Rua Desembargador Motta'},
#         {u'absoluteDirection': u'EAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 511.43100000000004,
#          u'elevation': [],
#          u'lat': -25.438903200000002,
#          u'lon': -49.2790608,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Doutor Pedrosa'},
#         {u'absoluteDirection': u'NORTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 30.43,
#          u'elevation': [],
#          u'lat': -25.4370717,
#          u'lon': -49.2743964,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Pra\xe7a Rui Barbosa'}],
#        u'to': {u'arrival': 1498939085000,
#         u'lat': -25.4367920278,
#         u'lon': -49.2744468121,
#         u'name': u'Destination',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'transitLeg': False}],
#      u'startTime': 1498938573000,
#      u'tooSloped': False,
#      u'transfers': 0,
#      u'transitTime': 0,
#      u'waitingTime': 0,
#      u'walkDistance': 653.8953759366109,
#      u'walkLimitExceeded': False,
#      u'walkTime': 512}],
#    u'to': {u'lat': -25.4367920278,
#     u'lon': -49.2744468121,
#     u'name': u'Destination',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'}},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4392036083,-49.2798294196',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_860',
#    u'startTransitStopId': u'1_3280',
#    u'time': u'16:49:33',
#    u'toPlace': u'-25.4367920278,-49.2744468121'}},
#  240518168651L: {u'debugOutput': {u'pathCalculationTime': 78,
#    u'pathTimes': [],
#    u'precalculationTime': 24,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 102},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4359762895,-49.266774864',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_474',
#    u'startTransitStopId': u'1_30749',
#    u'time': u'14:41:17',
#    u'toPlace': u'-25.4925665521,-49.2050732061'}},
#  240518168663L: {u'debugOutput': {u'pathCalculationTime': 16,
#    u'pathTimes': [16],
#    u'precalculationTime': 17,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 33},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'plan': {u'date': 1498956000000,
#    u'from': {u'lat': -25.4519810187,
#     u'lon': -49.265311975,
#     u'name': u'Origin',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'},
#    u'itineraries': [{u'duration': 1083,
#      u'elevationGained': 0.0,
#      u'elevationLost': 0.0,
#      u'endTime': 1498957083000,
#      u'legs': [{u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 1394.4750000000001,
#        u'duration': 1083.0,
#        u'endTime': 1498957083000,
#        u'from': {u'departure': 1498956000000,
#         u'lat': -25.4519810187,
#         u'lon': -49.265311975,
#         u'name': u'Origin',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 29,
#         u'points': u'zajzCfcukHCGIUkA{DuAyEWy@Ma@Sq@EMEKk@qBa@wAaBkFnAg@fAa@I_BQoEG{BEgAAS?iA??A{@O{ECi@YoFC_EjAGLA'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498956000000,
#        u'steps': [{u'absoluteDirection': u'NORTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 573.681,
#          u'elevation': [],
#          u'lat': -25.45197163562005,
#          u'lon': -49.26531697756404,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Rua Conselheiro Dantas'},
#         {u'absoluteDirection': u'SOUTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 92.02,
#          u'elevation': [],
#          u'lat': -25.4498627,
#          u'lon': -49.2601029,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Rua Rockefeller'},
#         {u'absoluteDirection': u'EAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 679.263,
#          u'elevation': [],
#          u'lat': -25.450620100000002,
#          u'lon': -49.259733600000004,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Comendador Roseira'},
#         {u'absoluteDirection': u'SOUTH',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 49.511,
#          u'elevation': [],
#          u'lat': -25.4501485,
#          u'lon': -49.2529923,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Rua Imaculada Concei\xe7\xe3o'}],
#        u'to': {u'arrival': 1498957083000,
#         u'lat': -25.4505932218,
#         u'lon': -49.252961375,
#         u'name': u'Destination',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'transitLeg': False}],
#      u'startTime': 1498956000000,
#      u'tooSloped': False,
#      u'transfers': 0,
#      u'transitTime': 0,
#      u'waitingTime': 0,
#      u'walkDistance': 1394.5795112748233,
#      u'walkLimitExceeded': False,
#      u'walkTime': 1083}],
#    u'to': {u'lat': -25.4505932218,
#     u'lon': -49.252961375,
#     u'name': u'Destination',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'}},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4519810187,-49.265311975',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_11',
#    u'startTransitStopId': u'1_32768',
#    u'time': u'21:40:00',
#    u'toPlace': u'-25.4505932218,-49.252961375'}},
#  274877907051L: {u'debugOutput': {u'pathCalculationTime': 26,
#    u'pathTimes': [],
#    u'precalculationTime': 23,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 49},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.3812840345,-49.2693829347',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_180',
#    u'startTransitStopId': u'1_28630',
#    u'time': u'08:00:00',
#    u'toPlace': u'-25.431579889,-49.2727372132'}},
#  343597383815L: {u'debugOutput': {u'pathCalculationTime': 36,
#    u'pathTimes': [36],
#    u'precalculationTime': 31,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 67},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'plan': {u'date': 1498898182000,
#    u'from': {u'lat': -25.4364342261,
#     u'lon': -49.2727682806,
#     u'name': u'Origin',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'},
#    u'itineraries': [{u'duration': 1058,
#      u'elevationGained': 0.0,
#      u'elevationLost': 0.0,
#      u'endTime': 1498899240000,
#      u'legs': [{u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 1356.6909999999998,
#        u'duration': 1058.0,
#        u'endTime': 1498899240000,
#        u'from': {u'departure': 1498898182000,
#         u'lat': -25.4364342261,
#         u'lon': -49.2727682806,
#         u'name': u'Origin',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 23,
#         u'points': u't`gzCzqvkHBLPj@@DXz@hIyCDN^hA`@Vb@lAlDqAn@WPEPEnGuB\\MhGiCVK|EiBjAe@rGcCp@hCXbA'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498898182000,
#        u'steps': [{u'absoluteDirection': u'SOUTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 68.827,
#          u'elevation': [],
#          u'lat': -25.436420680426103,
#          u'lon': -49.27277474760384,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Rua Andr\xe9 de Barros'},
#         {u'absoluteDirection': u'SOUTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 199.294,
#          u'elevation': [],
#          u'lat': -25.4366747,
#          u'lon': -49.273399700000006,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Alferes Poli'},
#         {u'absoluteDirection': u'SOUTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 49.255,
#          u'elevation': [],
#          u'lat': -25.438326,
#          u'lon': -49.272628100000006,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Avenida Visconde de Guarapuava'},
#         {u'absoluteDirection': u'SOUTHWEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 66.691,
#          u'elevation': [],
#          u'lat': -25.4385134,
#          u'lon': -49.273072500000005,
#          u'relativeDirection': u'SLIGHTLY_LEFT',
#          u'stayOn': False,
#          u'streetName': u'Avenida Visconde de Guarapuava'},
#         {u'absoluteDirection': u'SOUTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 861.549,
#          u'elevation': [],
#          u'lat': -25.438862200000003,
#          u'lon': -49.2735871,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Vinte e Quatro de Maio'},
#         {u'absoluteDirection': u'WEST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 111.075,
#          u'elevation': [],
#          u'lat': -25.4459811,
#          u'lon': -49.2702077,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Rua Engenheiros Rebou\xe7as'}],
#        u'to': {u'arrival': 1498899240000,
#         u'lat': -25.4463335532,
#         u'lon': -49.2712433009,
#         u'name': u'Destination',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'transitLeg': False}],
#      u'startTime': 1498898182000,
#      u'tooSloped': False,
#      u'transfers': 0,
#      u'transitTime': 0,
#      u'waitingTime': 0,
#      u'walkDistance': 1356.8526541301221,
#      u'walkLimitExceeded': False,
#      u'walkTime': 1058}],
#    u'to': {u'lat': -25.4463335532,
#     u'lon': -49.2712433009,
#     u'name': u'Destination',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'}},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4364342261,-49.2727682806',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_180',
#    u'startTransitStopId': u'1_26201',
#    u'time': u'05:36:22',
#    u'toPlace': u'-25.4463335532,-49.2712433009'}},
#  420906795142L: {u'debugOutput': {u'pathCalculationTime': 31,
#    u'pathTimes': [],
#    u'precalculationTime': 14,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 45},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
# ...
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4905110592,-49.3487808478',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_658',
#    u'startTransitStopId': u'1_35706',
#    u'time': u'13:16:37',
#    u'toPlace': u'-25.4941608105,-49.3060465852'}},
#  1340029796526L: {u'debugOutput': {u'pathCalculationTime': 27,
#    u'pathTimes': [],
#    u'precalculationTime': 20,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 47},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4442898661,-49.2913136997',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_370',
#    u'startTransitStopId': u'1_30157',
#    u'time': u'13:47:56',
#    u'toPlace': u'-25.4319087056,-49.267914492'}},
#  1348619731021L: {u'debugOutput': {u'pathCalculationTime': 25,
#    u'pathTimes': [25],
#    u'precalculationTime': 29,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 54},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'plan': {u'date': 1498935626000,
#    u'from': {u'lat': -25.4294390918,
#     u'lon': -49.2852205404,
#     u'name': u'Origin',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'},
#    u'itineraries': [{u'duration': 1061,
#      u'elevationGained': 0.0,
#      u'elevationLost': 0.0,
#      u'endTime': 1498936687000,
#      u'legs': [{u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 1373.5610000000004,
#        u'duration': 1061.0,
#        u'endTime': 1498936687000,
#        u'from': {u'departure': 1498935626000,
#         u'lat': -25.4294390918,
#         u'lon': -49.2852205404,
#         u'name': u'Origin',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 28,
#         u'points': u'fuezCt_ykHTmBNwAp@wGN_@^eApByFNc@bBmIV_A??`@}AISc@mB[qAq@eCOk@AEiAgEkAaEWgAm@}Bs@}CAODKHKDA@A'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498935626000,
#        u'steps': [{u'absoluteDirection': u'EAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 725.9580000000002,
#          u'elevation': [],
#          u'lat': -25.429478201125587,
#          u'lon': -49.285229479410674,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Rua Professor Fernando Moreira'},
#         {u'absoluteDirection': u'NORTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 627.4430000000001,
#          u'elevation': [],
#          u'lat': -25.4315922,
#          u'lon': -49.2784343,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Cruz Machado'},
#         {u'absoluteDirection': u'SOUTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 6.507,
#          u'elevation': [],
#          u'lat': -25.4295189,
#          u'lon': -49.2726285,
#          u'relativeDirection': u'RIGHT',
#          u'stayOn': False,
#          u'streetName': u'Pra\xe7a Tiradentes'},
#         {u'absoluteDirection': u'SOUTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 13.652999999999999,
#          u'elevation': [],
#          u'lat': -25.4295431,
#          u'lon': -49.2725695,
#          u'relativeDirection': u'SLIGHTLY_RIGHT',
#          u'stayOn': True,
#          u'streetName': u'Pra\xe7a Tiradentes'}],
#        u'to': {u'arrival': 1498936687000,
#         u'lat': -25.429667224,
#         u'lon': -49.2725645062,
#         u'name': u'Destination',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'transitLeg': False}],
#      u'startTime': 1498935626000,
#      u'tooSloped': False,
#      u'transfers': 0,
#      u'transitTime': 0,
#      u'waitingTime': 0,
#      u'walkDistance': 1373.618142855299,
#      u'walkLimitExceeded': False,
#      u'walkTime': 1061}],
#    u'to': {u'lat': -25.429667224,
#     u'lon': -49.2725645062,
#     u'name': u'Destination',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'}},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4294390918,-49.2852205404',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_870',
#    u'startTransitStopId': u'1_31932',
#    u'time': u'16:00:26',
#    u'toPlace': u'-25.429667224,-49.2725645062'}},
#  1425929142383L: {u'debugOutput': {u'pathCalculationTime': 29,
#    u'pathTimes': [],
#    u'precalculationTime': 14,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 43},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.5012698934,-49.2375507059',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_30',
#    u'startTransitStopId': u'1_270',
#    u'time': u'14:04:38',
#    u'toPlace': u'-25.4793908156,-49.2153201263'}},
#  1468878815353L: {u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 409,
#    u'message': u'TOO_CLOSE',
#    u'msg': u'Origin is within a trivial distance of the destination.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4189832039,-49.351245119',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_812',
#    u'startTransitStopId': u'1_30336',
#    u'time': u'16:38:09',
#    u'toPlace': u'-25.4190619047,-49.3493598892'}},
#  1546188226669L: {u'debugOutput': {u'pathCalculationTime': 1,
#    u'pathTimes': [1],
#    u'precalculationTime': 11,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 12},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'plan': {u'date': 1498943290000,
#    u'from': {u'lat': -25.4971046448,
#     u'lon': -49.216055481,
#     u'name': u'Origin',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'},
#    u'itineraries': [{u'duration': 279,
#      u'elevationGained': 0.0,
#      u'elevationLost': 0.0,
#      u'endTime': 1498943569000,
#      u'legs': [{u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 358.02799999999996,
#        u'duration': 279.0,
#        u'endTime': 1498943569000,
#        u'from': {u'departure': 1498943290000,
#         u'lat': -25.4971046448,
#         u'lon': -49.216055481,
#         u'name': u'Origin',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 11,
#         u'points': u'`|rzCnokkHVi@HMjAsB`AkBnBkDNYZi@?Ab@s@DG'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498943290000,
#        u'steps': [{u'absoluteDirection': u'SOUTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 358.02799999999996,
#          u'elevation': [],
#          u'lat': -25.49712496665659,
#          u'lon': -49.216070266865906,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Avenida Senador Salgado Filho'}],
#        u'to': {u'arrival': 1498943569000,
#         u'lat': -25.4989758553,
#         u'lon': -49.213151123,
#         u'name': u'Destination',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'transitLeg': False}],
#      u'startTime': 1498943290000,
#      u'tooSloped': False,
#      u'transfers': 0,
#      u'transitTime': 0,
#      u'waitingTime': 0,
#      u'walkDistance': 358.03138345853745,
#      u'walkLimitExceeded': False,
#      u'walkTime': 279}],
#    u'to': {u'lat': -25.4989758553,
#     u'lon': -49.213151123,
#     u'name': u'Destination',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'}},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4971046448,-49.216055481',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_338',
#    u'startTransitStopId': u'1_30085',
#    u'time': u'18:08:10',
#    u'toPlace': u'-25.4989758553,-49.213151123'}},
#  1580547964991L: {u'debugOutput': {u'pathCalculationTime': 67,
#    u'pathTimes': [],
#    u'precalculationTime': 31,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 98},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4303355108,-49.2671245868',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_380',
#    u'startTransitStopId': u'1_26376',
#    u'time': u'22:31:38',
#    u'toPlace': u'-25.4454910768,-49.3044413238'}},
#  1675037245583L: {u'debugOutput': {u'pathCalculationTime': 25,
#    u'pathTimes': [25],
#    u'precalculationTime': 37,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 62},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'plan': {u'date': 1498931503000,
#    u'from': {u'lat': -25.4180942867,
#     u'lon': -49.2686932868,
#     u'name': u'Origin',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'},
#    u'itineraries': [{u'duration': 946,
#      u'elevationGained': 0.0,
#      u'elevationLost': 0.0,
#      u'endTime': 1498932449000,
#      u'legs': [{u'agencyTimeZoneOffset': -10800000,
#        u'arrivalDelay': 0,
#        u'departureDelay': 0,
#        u'distance': 1219.2830000000004,
#        u'duration': 946.0,
#        u'endTime': 1498932449000,
#        u'from': {u'departure': 1498931503000,
#         u'lat': -25.4180942867,
#         u'lon': -49.2686932868,
#         u'name': u'Origin',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'interlineWithPreviousLeg': False,
#        u'legGeometry': {u'length': 33,
#         u'points': u'dnczC`xukHnC\\rHpAF@J@jCd@fHdA~Cd@v@HbBPF@PBTBlDh@D@J@zB^xDf@rCd@\\FFAF?XDf@BNMJOTYDGDEBEDCDG?A'},
#        u'mode': u'WALK',
#        u'pathway': False,
#        u'realTime': False,
#        u'rentedBike': False,
#        u'route': u'',
#        u'startTime': 1498931503000,
#        u'steps': [{u'absoluteDirection': u'SOUTH',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 711.6790000000001,
#          u'elevation': [],
#          u'lat': -25.418101426090665,
#          u'lon': -49.26864914293905,
#          u'relativeDirection': u'DEPART',
#          u'stayOn': False,
#          u'streetName': u'Avenida C\xe2ndido de Abreu'},
#         {u'absoluteDirection': u'SOUTH',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 399.421,
#          u'elevation': [],
#          u'lat': -25.4243589,
#          u'lon': -49.2701245,
#          u'relativeDirection': u'CONTINUE',
#          u'stayOn': False,
#          u'streetName': u'Rua Bar\xe3o do Serro Azul'},
#         {u'absoluteDirection': u'SOUTH',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 45.387,
#          u'elevation': [],
#          u'lat': -25.4278684,
#          u'lon': -49.270969300000004,
#          u'relativeDirection': u'SLIGHTLY_LEFT',
#          u'stayOn': True,
#          u'streetName': u'Rua Bar\xe3o do Serro Azul'},
#         {u'absoluteDirection': u'SOUTHEAST',
#          u'area': False,
#          u'bogusName': False,
#          u'distance': 62.796,
#          u'elevation': [],
#          u'lat': -25.4282721,
#          u'lon': -49.271003400000005,
#          u'relativeDirection': u'LEFT',
#          u'stayOn': False,
#          u'streetName': u'Rua Prefeito Jo\xe3o Moreira Garcez'}],
#        u'to': {u'arrival': 1498932449000,
#         u'lat': -25.4286630465,
#         u'lon': -49.2705538534,
#         u'name': u'Destination',
#         u'orig': u'',
#         u'vertexType': u'NORMAL'},
#        u'transitLeg': False}],
#      u'startTime': 1498931503000,
#      u'tooSloped': False,
#      u'transfers': 0,
#      u'transitTime': 0,
#      u'waitingTime': 0,
#      u'walkDistance': 1219.330368419524,
#      u'walkLimitExceeded': False,
#      u'walkTime': 946}],
#    u'to': {u'lat': -25.4286630465,
#     u'lon': -49.2705538534,
#     u'name': u'Destination',
#     u'orig': u'',
#     u'vertexType': u'NORMAL'}},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4180942867,-49.2686932868',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_272',
#    u'startTransitStopId': u'1_28925',
#    u'time': u'14:51:43',
#    u'toPlace': u'-25.4286630465,-49.2705538534'}},
#  1709396983854L: {u'debugOutput': {u'pathCalculationTime': 25,
#    u'pathTimes': [],
#    u'precalculationTime': 24,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 49},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.4749075065,-49.2270987151',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_468',
#    u'startTransitStopId': u'1_31508',
#    u'time': u'13:44:52',
#    u'toPlace': u'-25.4339206935,-49.2615723198'}},
#  1709396983939L: {u'debugOutput': {u'pathCalculationTime': 37,
#    u'pathTimes': [],
#    u'precalculationTime': 13,
#    u'renderingTime': 0,
#    u'timedOut': False,
#    u'totalTime': 50},
#   u'elevationMetadata': {u'ellipsoidToGeoidDifference': 3.6861111059479486,
#    u'geoidElevation': False},
#   u'error': {u'id': 404,
#    u'message': u'PATH_NOT_FOUND',
#    u'msg': u'No trip found. There may be no transit service within the maximum specified distance or at the specified time, or your start or end point might not be safely accessible.',
#    u'noPath': True},
#   u'requestParameters': {u'date': u'2017-07-01',
#    u'fromPlace': u'-25.372062488,-49.2461705155',
#    u'maxTransfers': u'0',
#    u'maxWalkingDistance': u'150',
#    u'mode': u'TRANSIT,WALK',
#    u'numItineraries': u'1',
#    u'preferredRoutes': u'URBS_272',
#    u'startTransitStopId': u'1_27222',
#    u'time': u'12:18:35',
#    u'toPlace': u'-25.4095475814,-49.2568924031'}}}

# %%
extract_otp_trips_legs(executed_trips_schedule)
# Out:
# [(1498898182,
#   343597383815L,
#   1,
#   1,
#   1498898182L,
#   1498899240L,
#   u'WALK',
#   None,
#   None,
#   None,
#   17L),
#  (1498898387,
#   34359738511L,
#   1,
#   1,
#   1498898819L,
#   1498900042L,
#   u'WALK',
#   None,
#   None,
#   None,
#   20L),
#  (1498898387,
#   34359738511L,
#   1,
#   2,
#   1498900043L,
#   1498900500L,
#   u'BUS',
#   u'500',
#   u'25471',
#   u'27560',
#   7L),
#  (1498898387,
#   34359738511L,
#   1,
#   3,
#   1498900501L,
#   1498900719L,
#   u'WALK',
#   None,
#   None,
#   None,
#   3L),
#  (1498928825,
#   128849018906L,
#   1,
#   1,
#   1498929421L,
#   1498930232L,
#   u'WALK',
#   None,
#   None,
#   None,
#   13L),
#  (1498928825,
#   128849018906L,
#   1,
#   2,
#   1498930233L,
#   1498930320L,
#   u'BUS',
#   u'500',
#   u'25515',
#   u'27560',
#   1L),
#  (1498928825,
#   128849018906L,
#   1,
#   3,
#   1498930321L,
#   1498931137L,
#   u'WALK',
#   None,
#   None,
#   None,
#   13L),
#  (1498938121,
#   1142461300763L,
#   1,
#   1,
#   1498938121L,
#   1498938579L,
#   u'WALK',
#   None,
#   None,
#   None,
#   7L),
#  (1498907314,
#   1279900254237L,
#   1,
#   1,
#   1498907314L,
#   1498908004L,
#   u'WALK',
#   None,
#   None,
#   None,
#   11L),
#  (1498924995,
#   111669149726L,
#   1,
#   1,
#   1498924995L,
#   1498926483L,
#   u'WALK',
#   None,
#   None,
#   None,
#   24L),
#  (1498933561,
#   1236950581425L,
#   1,
#   1,
#   1498996520L,
#   1498996799L,
#   u'WALK',
#   None,
#   None,
#   None,
#   4L),
#  (1498933561,
#   1236950581425L,
#   1,
#   2,
#   1498996800L,
#   1498997229L,
#   u'BUS',
#   u'688',
#   u'31047',
#   u'29992',
#   7L),
#  (1498933561,
#   1236950581425L,
#   1,
#   3,
#   1498997230L,
#   1498998077L,
#   u'WALK',
#   None,
#   None,
#   None,
#   14L),
#  (1498943252,
#   858993459358L,
#   1,
#   1,
#   1498943252L,
#   1498944243L,
#   u'WALK',
#   None,
#   None,
#   None,
#   16L),
#  (1498919845,
#   721554505844L,
#   1,
#   1,
#   1498919845L,
#   1498919966L,
#   u'WALK',
#   None,
#   None,
#   None,
#   2L),
#  (1498946513,
#   1047972020291L,
#   1,
#   1,
#   1498946513L,
#   1498946699L,
#   u'WALK',
#   None,
#   None,
#   None,
#   3L),
#  (1498943995,
#   867583393861L,
#   1,
#   1,
#   1498943995L,
#   1498944418L,
#   u'WALK',
#   None,
#   None,
#   None,
#   7L),
#  (1498935626,
#   1348619731021L,
#   1,
#   1,
#   1498935626L,
#   1498936687L,
#   u'WALK',
#   None,
#   None,
#   None,
#   17L),
#  (1498903138,
#   68719476815L,
#   1,
#   1,
#   1498903138L,
#   1498904501L,
#   u'WALK',
#   None,
#   None,
#   None,
#   22L),
#  (1498956000,
#   240518168663L,
#   1,
#   1,
#   1498956000L,
#   1498957083L,
#   u'WALK',
#   None,
#   None,
#   None,
#   18L),
#  (1498928268,
#   695784702041L,
#   1,
#   1,
#   1498928268L,
#   1498928839L,
#   u'WALK',
#   None,
#   None,
#   None,
#   9L),
#  (1498931503,
#   1675037245583L,
#   1,
#   1,
#   1498931503L,
#   1498932449L,
#   u'WALK',
#   None,
#   None,
#   None,
#   15L),
#  (1498938573,
#   146028888172L,
#   1,
#   1,
#   1498938573L,
#   1498939085L,
#   u'WALK',
#   None,
#   None,
#   None,
#   8L),
#  (1498943290,
#   1546188226669L,
#   1,
#   1,
#   1498943290L,
#   1498943569L,
#   u'WALK',
#   None,
#   None,
#   None,
#   4L),
#  (1498917939,
#   1297080123496L,
#   1,
#   1,
#   1498917939L,
#   1498918417L,
#   u'WALK',
#   None,
#   None,
#   None,
#   7L),
#  (1498906610,
#   1116691497084L,
#   1,
#   1,
#   1498906610L,
#   1498907571L,
#   u'WALK',
#   None,
#   None,
#   None,
#   16L)]

# %%
print "Extracting OTP Legs info..."
executed_trips_schedule_df = prepare_otp_legs_df(extract_otp_trips_legs(executed_trips_schedule)) \
                                .filter('mode == \'BUS\'') \
                                .withColumn('itinerary_id',F.lit(0))

#executed_trips_schedule = None
# Out:
# Extracting OTP Legs info...

# %%
printdf(executed_trips_schedule_df.orderBy(['user_trip_id']))
# Out:
#          date   user_trip_id  itinerary_id  leg_id      otp_start_time  \
# 0  2017-07-01    34359738511             0       2 2017-07-01 06:07:23
# 1  2017-07-01   128849018906             0       2 2017-07-01 14:30:33
# 2  2017-07-01  1236950581425             0       2 2017-07-02 09:00:00
#
#          otp_end_time mode  route  from_stop_id  to_stop_id  otp_duration_mins
# 0 2017-07-01 06:15:00  BUS    500         25471       27560           7.616667
# 1 2017-07-01 14:32:00  BUS    500         25515       27560           1.450000
# 2 2017-07-02 09:07:09  BUS    688         31047       29992           7.150000

# %%
printdf(od_matrix.select(['date','user_trip_id','o_base_datetime','route','o_stop_id','stopPointId','next_o_stop_id']).orderBy(['user_trip_id']))
# Out:
#          date  user_trip_id      o_base_datetime  route  o_stop_id  \
# 0  2017-07-01   17179869310  2017-07-01 12:59:31     21      29097
# 1  2017-07-01   17179869337  2017-07-01 15:52:39    176      28556
# 2  2017-07-01   34359738511  2017-07-01 05:39:47    475      33479
# 3  2017-07-01   42949672972  2017-07-01 20:33:27    650      32036
# 4  2017-07-01   68719476815  2017-07-01 06:58:58    663      26631
# 5  2017-07-01   85899345938  2017-07-01 05:49:53    619      36280
# 6  2017-07-01  111669149726  2017-07-01 13:03:15    629      29839
# 7  2017-07-01  120259084404  2017-07-01 19:01:58    658      35869
# 8  2017-07-01  128849018906  2017-07-01 14:07:05    160      26629
# 9  2017-07-01  128849018984  2017-07-01 13:59:56    673      26630
#
#    stopPointId  next_o_stop_id
# 0        31874           31874
# 1        37134           28758
# 2        26174           28592
# 3        36275           36275
# 4        29142           31986
# 5        33246           32038
# 6        29858            5109
# 7        32720           32165
# 8        26720           33905
# 9        32157           29865

# %%
matched_executed_trips = od_matrix \
                     .withColumnRenamed('o_stop_id','from_stop_id') \
                     .withColumnRenamed('stopPointId','to_stop_id') \
                .join(executed_trips_schedule_df, \
                    on=['date','user_trip_id','from_stop_id','to_stop_id'], how='inner') \
                .select(['date','user_trip_id','itinerary_id','otp_duration_mins','otp_start_time']) \
                .withColumnRenamed('otp_duration_mins','planned_duration_mins') \
                .withColumnRenamed('otp_start_time','planned_start_time')
printdf(matched_executed_trips)
# Out:
# Empty DataFrame
# Columns: [date, user_trip_id, itinerary_id, planned_duration_mins, planned_start_time]
# Index: []

# %%
matched_executed_trips.count()
# Out:
# 0

# %%
od_matrix.count()
# Out:
# 50

# %%
executed_trips_schedule_df.count()
# Out:
# 3

# %% [markdown]
# #### Printing Itineraries Stats

# %%
total_num_itineraries = otp_legs_df.select('user_trip_id','itinerary_id').distinct().count()
total_num_legs = otp_legs_df.count()
num_bus_legs = otp_legs_df.filter('mode == \'BUS\'').count()

print "Total num itineraries:", total_num_itineraries
print "Total num legs:", total_num_legs
print "Total num bus legs:", num_bus_legs, '(', 100*(num_bus_legs/float(total_num_legs)), '%)'
# Out:
# Total num itineraries: 28
# Total num legs: 50
# Total num bus legs: 11 ( 22.0 %)

# %% [markdown]
# #### Matching OTP Bus Legs Origins with BUSTE Data

# %%
print "Reading BUSTE data..."
bus_trips_data = read_folders(buste_data_folderpath, sqlContext, sc, initial_date, final_date,'')
clean_bus_trips_data = clean_buste_data(bus_trips_data)

print "Finding OTP Bus Legs Actual Start Times in Bus Trips Data..."
otp_legs_st = find_otp_bus_legs_actual_start_time(otp_legs_df,clean_bus_trips_data)
# Out:
# Reading BUSTE data...
# Finding OTP Bus Legs Actual Start Times in Bus Trips Data...

# %%
bus_trips_data.printSchema()
# Out:
# root
#  |-- route: string (nullable = true)
#  |-- tripNum: integer (nullable = true)
#  |-- shapeId: integer (nullable = true)
#  |-- shapeSequence: integer (nullable = true)
#  |-- shapeLat: double (nullable = true)
#  |-- shapeLon: double (nullable = true)
#  |-- distanceTraveledShape: double (nullable = true)
#  |-- busCode: string (nullable = true)
#  |-- gpsPointId: string (nullable = true)
#  |-- gpsLat: double (nullable = true)
#  |-- gpsLon: double (nullable = true)
#  |-- distanceToShapePoint: double (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- stopPointId: integer (nullable = true)
#  |-- problem: string (nullable = true)
#  |-- birthdate: string (nullable = true)
#  |-- cardTimestamp: string (nullable = true)
#  |-- lineName: string (nullable = true)
#  |-- cardNum: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- date: long (nullable = true)

# %%
printdf(clean_bus_trips_data)
# Out:
#          date  route busCode  tripNum  stopPointId            timestamp
# 0  2017-07-01   21.0   HB606        2        33004  2017-07-01 08:53:05
# 1  2017-07-01   21.0   HB606        6        33006  2017-07-01 17:52:30
# 2  2017-07-01   40.0   LB602        4        31029  2017-07-01 14:45:43
# 3  2017-07-01   40.0   LB602        4        34110  2017-07-01 13:01:33
# 4  2017-07-01   40.0   LB602        4        35758  2017-07-01 12:26:10
# 5  2017-07-01    1.0   BN999        3        31454  2017-07-01 07:24:14
# 6  2017-07-01    1.0   BN999        5        26166  2017-07-01 08:18:24
# 7  2017-07-01    1.0   BN999       17        30748  2017-07-01 12:42:52
# 8  2017-07-01   10.0   BB303        4        28647  2017-07-01 09:55:53
# 9  2017-07-01   11.0   BB305        7        29134  2017-07-01 12:37:48

# %%
printdf(otp_legs_df)
# Out:
#          date  user_trip_id  itinerary_id  leg_id      otp_start_time  \
# 0  2017-07-01   34359738511             1       1 2017-07-01 05:46:59
# 1  2017-07-01   34359738511             1       2 2017-07-01 06:07:23
# 2  2017-07-01   34359738511             1       3 2017-07-01 06:15:01
# 3  2017-07-01   34359738511             2       1 2017-07-01 06:06:59
# 4  2017-07-01   34359738511             2       2 2017-07-01 06:27:23
# 5  2017-07-01   34359738511             2       3 2017-07-01 06:35:01
# 6  2017-07-01   34359738511             3       1 2017-07-01 06:16:59
# 7  2017-07-01   34359738511             3       2 2017-07-01 06:37:23
# 8  2017-07-01   34359738511             3       3 2017-07-01 06:45:01
# 9  2017-07-01   68719476815             1       1 2017-07-01 06:58:58
#
#          otp_end_time  mode  route  from_stop_id  to_stop_id  \
# 0 2017-07-01 06:07:22  WALK    NaN           NaN         NaN
# 1 2017-07-01 06:15:00   BUS  500.0       25471.0     27560.0
# 2 2017-07-01 06:18:39  WALK    NaN           NaN         NaN
# 3 2017-07-01 06:27:22  WALK    NaN           NaN         NaN
# 4 2017-07-01 06:35:00   BUS  500.0       25471.0     27560.0
# 5 2017-07-01 06:38:39  WALK    NaN           NaN         NaN
# 6 2017-07-01 06:37:22  WALK    NaN           NaN         NaN
# 7 2017-07-01 06:45:00   BUS  500.0       25471.0     27560.0
# 8 2017-07-01 06:48:39  WALK    NaN           NaN         NaN
# 9 2017-07-01 07:21:41  WALK    NaN           NaN         NaN
#
#    otp_duration_mins
# 0          20.383333
# 1           7.616667
# 2           3.633333
# 3          20.383333
# 4           7.616667
# 5           3.633333
# 6          20.383333
# 7           7.616667
# 8           3.633333
# 9          22.716667

# %% [markdown]
# #### Printing Matched OTP Bus Legs Origins Stats

# %%
num_bus_legs_st = otp_legs_st.count()
print "Num Bus Legs whose start was found:", num_bus_legs_st, '(', 100*(num_bus_legs_st/float(num_bus_legs)), '%)'
# Out:
# Num Bus Legs whose start was found: 6 ( 54.5454545455 %)

# %% [markdown]
# #### Cleaning Memory

# %%
#Clean memory
#otp_legs_df.unpersist(blocking=True)
#bus_trips_data.unpersist(blocking=True)
#clean_bus_trips_data.unpersist(blocking=True)

# %% [markdown]
# #### Matching OTP Bus Legs Destinations with BUSTE Data

# %%
print "Reading BUSTE data again..."
bus_trips_data2 = read_folders(buste_data_folderpath, sqlContext, sc, initial_date, final_date,'')
clean_bus_trips_data2 = clean_buste_data(bus_trips_data2)

print "Finding OTP Bus Legs Actual End Times in Bus Trips Data..."
otp_legs_start_end = find_otp_bus_legs_actual_end_time(otp_legs_st,clean_bus_trips_data2)
clean_otp_legs_actual_time = clean_otp_legs_actual_time_df(otp_legs_start_end)
# Out:
# Reading BUSTE data again...
# Finding OTP Bus Legs Actual End Times in Bus Trips Data...

# %%
num_matched_bus_legs_st = clean_otp_legs_actual_time.count()
print "Num Bus Legs whose end was found:", num_matched_bus_legs_st, '(', 100*(num_matched_bus_legs_st/float(num_bus_legs)), '%)'
# Out:
# Num Bus Legs whose end was found: 5 ( 45.4545454545 %)

# %% [markdown]
# #### Cleaning Memory

# %%
#Clean Memory
#otp_legs_st.unpersist(blocking=True)
#bus_trips_data2.unpersist(blocking=True)
#clean_bus_trips_data2.unpersist(blocking=True)
#otp_legs_start_end.unpersist(blocking=True)

# %% [markdown]
# #### Enriching OTP suggestions legs with actual time data

# %%
print "Enriching OTP suggestions legs with actual time data..."
all_legs_actual_time = combine_otp_suggestions_with_bus_legs_actual_time(otp_legs_df,clean_otp_legs_actual_time)
# Out:
# Enriching OTP suggestions legs with actual time data...

# %% [markdown]
# #### Filtering out itineraries with bus legs not identified in bus data

# %%
print "Filtering out itineraries with bus legs not identified in bus data..."
clean_legs_actual_time = select_itineraries_fully_identified(all_legs_actual_time)
# Out:
# Filtering out itineraries with bus legs not identified in bus data...

# %%
print "Filtering out itineraries without bus legs..."
clean_legs_actual_time = filter_itineraries_without_bus_legs(clean_legs_actual_time)
# Out:
# Filtering out itineraries without bus legs...

# %%
printdf(clean_legs_actual_time)
# Out:
#          date  user_trip_id  itinerary_id  leg_id  route  from_stop_id  \
# 0  2017-07-01   34359738511             1       2  500.0       25471.0
# 1  2017-07-01   34359738511             1       3    NaN           NaN
# 2  2017-07-01   34359738511             1       1    NaN           NaN
# 3  2017-07-01  128849018906             2       2  500.0       25515.0
# 4  2017-07-01  128849018906             2       3    NaN           NaN
# 5  2017-07-01  128849018906             2       1    NaN           NaN
# 6  2017-07-01   34359738511             3       1    NaN           NaN
# 7  2017-07-01   34359738511             3       2  500.0       25471.0
# 8  2017-07-01   34359738511             3       3    NaN           NaN
# 9  2017-07-01   34359738511             2       3    NaN           NaN
#
#    to_stop_id      otp_start_time        otp_end_time  mode  \
# 0     27560.0 2017-07-01 06:07:23 2017-07-01 06:15:00   BUS
# 1         NaN 2017-07-01 06:15:01 2017-07-01 06:18:39  WALK
# 2         NaN 2017-07-01 05:46:59 2017-07-01 06:07:22  WALK
# 3     27560.0 2017-07-01 14:46:33 2017-07-01 14:48:00   BUS
# 4         NaN 2017-07-01 14:48:01 2017-07-01 15:01:37  WALK
# 5         NaN 2017-07-01 14:33:01 2017-07-01 14:46:32  WALK
# 6         NaN 2017-07-01 06:16:59 2017-07-01 06:37:22  WALK
# 7     27560.0 2017-07-01 06:37:23 2017-07-01 06:45:00   BUS
# 8         NaN 2017-07-01 06:45:01 2017-07-01 06:48:39  WALK
# 9         NaN 2017-07-01 06:35:01 2017-07-01 06:38:39  WALK
#
#    otp_duration_mins busCode  tripNum       from_timestamp  \
# 0           7.616667   GE716      1.0  2017-07-01 06:05:05
# 1           3.633333    None      NaN                 None
# 2          20.383333    None      NaN                 None
# 3           1.450000   GE700     11.0  2017-07-01 14:42:20
# 4          13.600000    None      NaN                 None
# 5          13.516667    None      NaN                 None
# 6          20.383333    None      NaN                 None
# 7           7.616667   GE702      1.0  2017-07-01 06:35:20
# 8           3.633333    None      NaN                 None
# 9           3.633333    None      NaN                 None
#
#           to_timestamp  actual_duration_mins  considered_duration_mins  \
# 0  2017-07-01 06:15:34             10.483333                 10.483333
# 1                 None                   NaN                  3.633333
# 2                 None                   NaN                 20.383333
# 3  2017-07-01 14:46:52              4.533333                  4.533333
# 4                 None                   NaN                 13.600000
# 5                 None                   NaN                 13.516667
# 6                 None                   NaN                 20.383333
# 7  2017-07-01 06:44:01              8.683333                  8.683333
# 8                 None                   NaN                  3.633333
# 9                 None                   NaN                  3.633333
#
#   considered_start_time
# 0   2017-07-01 06:05:05
# 1   2017-07-01 06:15:01
# 2   2017-07-01 05:46:59
# 3   2017-07-01 14:42:20
# 4   2017-07-01 14:48:01
# 5   2017-07-01 14:33:01
# 6   2017-07-01 06:16:59
# 7   2017-07-01 06:35:20
# 8   2017-07-01 06:45:01
# 9   2017-07-01 06:35:01

# %%
printdf(clean_legs_actual_time.filter(clean_legs_actual_time['mode'] == 'BUS') \
        .select(['otp_start_time','otp_end_time','otp_duration_mins','from_timestamp','to_timestamp','actual_duration_mins']))
# Out:
#        otp_start_time        otp_end_time  otp_duration_mins  \
# 0 2017-07-01 06:07:23 2017-07-01 06:15:00           7.616667
# 1 2017-07-01 14:46:33 2017-07-01 14:48:00           1.450000
# 2 2017-07-01 06:37:23 2017-07-01 06:45:00           7.616667
# 3 2017-07-01 06:27:23 2017-07-01 06:35:00           7.616667
# 4 2017-07-01 14:30:33 2017-07-01 14:32:00           1.450000
#
#         from_timestamp         to_timestamp  actual_duration_mins
# 0  2017-07-01 06:05:05  2017-07-01 06:15:34             10.483333
# 1  2017-07-01 14:42:20  2017-07-01 14:46:52              4.533333
# 2  2017-07-01 06:35:20  2017-07-01 06:44:01              8.683333
# 3  2017-07-01 06:23:54  2017-07-01 06:32:59              9.083333
# 4  2017-07-01 14:28:47  2017-07-01 14:33:30              4.716667

# %% [markdown]
# #### Printing Fully Identified OTP Itineraries Stats

# %%
num_itineraries_fully_identified = clean_legs_actual_time.select('user_trip_id','itinerary_id').distinct().count()
print "Num Itineraries fully identified in BUSTE data:", num_itineraries_fully_identified, '(', 100*(num_itineraries_fully_identified/float(total_num_itineraries)), '%)'
# Out:
# Num Itineraries fully identified in BUSTE data: 5 ( 17.8571428571 %)

# %%
print "Writing OTP suggested itineraries legs with actual time to file..."
#clean_legs_actual_time.write.csv(path=results_folderpath+'/otp_legs_matched',header=True, mode='append')
# Out:
# Writing OTP suggested itineraries legs with actual time to file...

# %%
#Clean Memory
#clean_otp_legs_actual_time.unpersist(blocking=True)
#all_legs_actual_time.unpersist(blocking=True)

# %%
printdf(od_matrix)
# Out:
#    route  tripNum  shapeId  shapeSequence   shapeLat   shapeLon  \
# 0    370        4     2789        5510497 -25.436972 -49.277444
# 1    380        6     4127        6448424 -25.427902 -49.263242
# 2    712        2     2170        6657911 -25.484518 -49.333416
# 3    211        7     1776        6633394 -25.402759 -49.213098
# 4    628        7     2935        6035542 -25.495496 -49.302459
# 5    183        7     1753        6096567 -25.428575 -49.271158
# 6    876        1     2937        6065893 -25.422933 -49.304968
# 7    463        7     2846        6348437 -25.479636 -49.193971
# 8    777        2     2195        4300046 -25.461139 -49.325868
# 9    462        5     3102        5855535 -25.434773 -49.272324
#
#    distanceTraveledShape busCode gpsPointId     gpsLat         ...           \
# 0               3768.768   BC032       None -25.437973         ...
# 1               6213.697   LC302       None -25.428101         ...
# 2               4717.637   JA012       None -25.484293         ...
# 3                  0.000   BA037       None -25.402765         ...
# 4              13282.360   HA025       None -25.495243         ...
# 5              10934.301   BC311       None -25.428583         ...
# 6               4090.977   BC300       None -25.422850         ...
# 7                  0.000   DC087       None -25.479658         ...
# 8               7161.699   JC012       None -25.461108         ...
# 9              12450.673   DC296       None -25.434785         ...
#
#    o_unixtimestamp  next_o_unixtimestamp leg_duration      dist rn  \
# 0            46949                 73805   447.600000  0.583099  1
# 1            65029                 75415   173.100000  0.020988  1
# 2            32680                 45992   221.866667  0.214177  1
# 3            76931                 39309    -1.000000  0.974592  1
# 4            57933                 72766   247.216667  0.368644  1
# 5            60800                 62505    28.416667  0.798145  1
# 6            32943                 64125   519.700000  0.904173  1
# 7            32479                 50924   307.416667  0.000000  1
# 8            38155                 31834    -1.000000  0.121724  1
# 9            52149                 49923    -1.000000  0.114577  1
#
#          date           o_datetime           d_datetime executed_duration  \
# 0  2017-05-09  2017-05-09 10:02:29  2017-05-09 10:45:35         43.100000
# 1  2017-05-09  2017-05-09 15:03:49  2017-05-09 15:56:29         52.666667
# 2  2017-05-09  2017-05-09 06:04:40  2017-05-09 06:24:55         20.250000
# 3  2017-05-09  2017-05-09 18:22:11  2017-05-09 19:08:20         46.150000
# 4  2017-05-09  2017-05-09 13:05:33  2017-05-09 13:38:32         32.983333
# 5  2017-05-09  2017-05-09 13:53:20  2017-05-09 14:28:34         35.233333
# 6  2017-05-09  2017-05-09 06:09:03  2017-05-09 06:50:39         41.600000
# 7  2017-05-09  2017-05-09 06:01:19  2017-05-09 13:12:29        431.166667
# 8  2017-05-09  2017-05-09 07:35:55  2017-05-09 07:45:22          9.450000
# 9  2017-05-09  2017-05-09 11:29:09  2017-05-09 11:59:30         30.350000
#
#        o_base_datetime
# 0  2017-05-09 10:00:29
# 1  2017-05-09 15:01:49
# 2  2017-05-09 06:02:40
# 3  2017-05-09 18:20:11
# 4  2017-05-09 13:03:33
# 5  2017-05-09 13:51:20
# 6  2017-05-09 06:07:03
# 7  2017-05-09 05:59:19
# 8  2017-05-09 07:33:55
# 9  2017-05-09 11:27:09
#
# [10 rows x 54 columns]

# %%
clean_legs_actual_time.printSchema()
# Out:
# root
#  |-- date: string (nullable = true)
#  |-- user_trip_id: long (nullable = true)
#  |-- itinerary_id: long (nullable = true)
#  |-- leg_id: long (nullable = true)
#  |-- route: integer (nullable = true)
#  |-- from_stop_id: integer (nullable = true)
#  |-- to_stop_id: integer (nullable = true)
#  |-- otp_start_time: timestamp (nullable = true)
#  |-- otp_end_time: timestamp (nullable = true)
#  |-- mode: string (nullable = true)
#  |-- otp_duration_mins: double (nullable = true)
#  |-- busCode: string (nullable = true)
#  |-- tripNum: integer (nullable = true)
#  |-- from_timestamp: string (nullable = true)
#  |-- to_timestamp: string (nullable = true)
#  |-- actual_duration_mins: double (nullable = true)
#  |-- considered_duration_mins: double (nullable = true)
#  |-- considered_start_time: string (nullable = true)

# %%
printdf(clean_legs_actual_time \
           .orderBy(['date','user_trip_id','itinerary_id','leg_id']))
# Out:
#          date  user_trip_id  itinerary_id  leg_id  route  from_stop_id  \
# 0  2017-05-09             7             1       1    NaN           NaN
# 1  2017-05-09             7             1       2  703.0       35271.0
# 2  2017-05-09             7             1       3    NaN           NaN
# 3  2017-05-09             7             2       1    NaN           NaN
# 4  2017-05-09             7             2       2  703.0       35271.0
# 5  2017-05-09             7             2       3    NaN           NaN
# 6  2017-05-09             7             3       1    NaN           NaN
# 7  2017-05-09             7             3       2  703.0       35271.0
# 8  2017-05-09             7             3       3    NaN           NaN
# 9  2017-05-09             8             1       1    NaN           NaN
#
#    to_stop_id      otp_start_time        otp_end_time  mode  \
# 0         NaN 2017-05-09 14:43:08 2017-05-09 14:43:18  WALK
# 1     26631.0 2017-05-09 14:43:19 2017-05-09 15:18:32   BUS
# 2         NaN 2017-05-09 15:18:33 2017-05-09 15:18:35  WALK
# 3         NaN 2017-05-09 14:56:08 2017-05-09 14:56:18  WALK
# 4     26631.0 2017-05-09 14:56:19 2017-05-09 15:31:32   BUS
# 5         NaN 2017-05-09 15:31:33 2017-05-09 15:31:35  WALK
# 6         NaN 2017-05-09 15:09:08 2017-05-09 15:09:18  WALK
# 7     26631.0 2017-05-09 15:09:19 2017-05-09 15:44:32   BUS
# 8         NaN 2017-05-09 15:44:33 2017-05-09 15:44:35  WALK
# 9         NaN 2017-05-09 06:30:42 2017-05-09 06:41:50  WALK
#
#    otp_duration_mins busCode  tripNum       from_timestamp  \
# 0           0.166667    None      NaN                 None
# 1          35.216667   JC310      6.0  2017-05-09 14:40:13
# 2           0.033333    None      NaN                 None
# 3           0.166667    None      NaN                 None
# 4          35.216667   JC304      7.0  2017-05-09 15:07:46
# 5           0.033333    None      NaN                 None
# 6           0.166667    None      NaN                 None
# 7          35.216667   JC304      7.0  2017-05-09 15:07:46
# 8           0.033333    None      NaN                 None
# 9          11.133333    None      NaN                 None
#
#           to_timestamp  actual_duration_mins  considered_duration_mins  \
# 0                 None                   NaN                  0.166667
# 1  2017-05-09 15:10:07             29.900000                 29.900000
# 2                 None                   NaN                  0.033333
# 3                 None                   NaN                  0.166667
# 4  2017-05-09 15:32:38             24.866667                 24.866667
# 5                 None                   NaN                  0.033333
# 6                 None                   NaN                  0.166667
# 7  2017-05-09 15:32:38             24.866667                 24.866667
# 8                 None                   NaN                  0.033333
# 9                 None                   NaN                 11.133333
#
#   considered_start_time
# 0   2017-05-09 14:43:08
# 1   2017-05-09 14:40:13
# 2   2017-05-09 15:18:33
# 3   2017-05-09 14:56:08
# 4   2017-05-09 15:07:46
# 5   2017-05-09 15:31:33
# 6   2017-05-09 15:09:08
# 7   2017-05-09 15:07:46
# 8   2017-05-09 15:44:33
# 9   2017-05-09 06:30:42

# %% [markdown]
# #### Gather all trips alternative/executed itineraries info

# %%
first_boarding_time = clean_legs_actual_time \
                        .filter('mode == \'BUS\'') \
                        .groupby(['date', 'user_trip_id', 'itinerary_id']) \
                        .agg(F.first('otp_start_time').alias('planned_start_time'), \
                             F.first('considered_start_time').alias('actual_start_time')) \
                        .orderBy(['date','user_trip_id','itinerary_id'])        
                
printdf(first_boarding_time)
# Out:
#          date  user_trip_id  itinerary_id  planned_start_time  \
# 0  2017-07-01   34359738511             1 2017-07-01 06:07:23
# 1  2017-07-01   34359738511             2 2017-07-01 06:27:23
# 2  2017-07-01   34359738511             3 2017-07-01 06:37:23
# 3  2017-07-01  128849018906             1 2017-07-01 14:30:33
# 4  2017-07-01  128849018906             2 2017-07-01 14:46:33
#
#      actual_start_time
# 0  2017-07-01 06:05:05
# 1  2017-07-01 06:23:54
# 2  2017-07-01 06:35:20
# 3  2017-07-01 14:28:47
# 4  2017-07-01 14:42:20

# %%
user_trips_time_info = od_matrix \
                        .withColumnRenamed('executed_duration','exec_duration_mins') \
                        .withColumnRenamed('o_datetime','exec_start_time') \
                        .select(['date','user_trip_id','exec_duration_mins','exec_start_time'])

printdf(user_trips_time_info)
# Out:
#          date   user_trip_id  exec_duration_mins      exec_start_time
# 0  2017-07-01   240518168663            5.033333  2017-07-01 21:42:00
# 1  2017-07-01    34359738511          450.433333  2017-07-01 05:41:47
# 2  2017-07-01   661424963588           28.266667  2017-07-01 14:52:03
# 3  2017-07-01  1709396983854           11.600000  2017-07-01 13:46:52
# 4  2017-07-01  1047972020291           64.533333  2017-07-01 19:03:53
# 5  2017-07-01   343597383815           58.100000  2017-07-01 05:38:22
# 6  2017-07-01    85899345938           19.766667  2017-07-01 05:51:53
# 7  2017-07-01   901943132161           22.166667  2017-07-01 19:03:41
# 8  2017-07-01  1073741824016           23.950000  2017-07-01 19:47:50
# 9  2017-07-01   420906795142            7.716667  2017-07-01 09:32:49

# %%
printdf(matched_executed_trips)
# Out:
# Empty DataFrame
# Columns: [date, user_trip_id, itinerary_id, planned_duration_mins, planned_start_time]
# Index: []

# %%
executed_legs = user_trips_time_info \
            .join(matched_executed_trips, on=['date','user_trip_id'], how='left') \
            .withColumn('actual_duration_mins',F.col('exec_duration_mins')) \
            .withColumn('actual_start_time',F.col('exec_start_time')) \
            .withColumn('itinerary_id',F.lit(0)) \
            .select(['date','user_trip_id','itinerary_id','planned_duration_mins','actual_duration_mins','exec_duration_mins',
                     'planned_start_time','actual_start_time','exec_start_time'])
            
printdf(executed_legs)
# Out:
#          date   user_trip_id  itinerary_id planned_duration_mins  \
# 0  2017-07-01   274877907051             0                  None
# 1  2017-07-01  1425929142383             0                  None
# 2  2017-07-01   867583393861             0                  None
# 3  2017-07-01    42949672972             0                  None
# 4  2017-07-01  1314259992746             0                  None
# 5  2017-07-01   128849018906             0                  None
# 6  2017-07-01   609885356211             0                  None
# 7  2017-07-01   858993459358             0                  None
# 8  2017-07-01  1236950581425             0                  None
# 9  2017-07-01  1580547964991             0                  None
#
#    actual_duration_mins  exec_duration_mins planned_start_time  \
# 0             25.166667           25.166667               None
# 1            107.933333          107.933333               None
# 2             24.083333           24.083333               None
# 3             12.000000           12.000000               None
# 4             24.600000           24.600000               None
# 5             13.833333           13.833333               None
# 6              4.950000            4.950000               None
# 7              5.983333            5.983333               None
# 8              7.533333            7.533333               None
# 9             28.650000           28.650000               None
#
#      actual_start_time      exec_start_time
# 0  2017-07-01 08:02:00  2017-07-01 08:02:00
# 1  2017-07-01 14:06:38  2017-07-01 14:06:38
# 2  2017-07-01 18:21:55  2017-07-01 18:21:55
# 3  2017-07-01 20:35:27  2017-07-01 20:35:27
# 4  2017-07-01 13:18:37  2017-07-01 13:18:37
# 5  2017-07-01 14:09:05  2017-07-01 14:09:05
# 6  2017-07-01 20:19:59  2017-07-01 20:19:59
# 7  2017-07-01 18:09:32  2017-07-01 18:09:32
# 8  2017-07-01 15:28:01  2017-07-01 15:28:01
# 9  2017-07-01 22:33:38  2017-07-01 22:33:38

# %%
matched_otp_legs = clean_legs_actual_time \
                            .groupBy(['date', 'user_trip_id', 'itinerary_id']) \
                            .agg(F.sum('otp_duration_mins').alias('planned_duration_mins'), \
                                 F.sum('considered_duration_mins').alias('actual_duration_mins')) \
                        .join(first_boarding_time, on=['date','user_trip_id','itinerary_id']) \
                        .join(user_trips_time_info, on=['date','user_trip_id'], how='inner') \
                        .orderBy(['date','user_trip_id','itinerary_id']) \
                        .select(['date','user_trip_id','itinerary_id','planned_duration_mins','actual_duration_mins','exec_duration_mins',
                     'planned_start_time','actual_start_time','exec_start_time'])
                 
printdf(matched_otp_legs)
# Out:
#          date  user_trip_id  itinerary_id  planned_duration_mins  \
# 0  2017-07-01   34359738511             1              31.633333
# 1  2017-07-01   34359738511             2              31.633333
# 2  2017-07-01   34359738511             3              31.633333
# 3  2017-07-01  128849018906             1              28.566667
# 4  2017-07-01  128849018906             2              28.566667
#
#    actual_duration_mins  exec_duration_mins  planned_start_time  \
# 0             34.500000          450.433333 2017-07-01 06:07:23
# 1             33.100000          450.433333 2017-07-01 06:27:23
# 2             32.700000          450.433333 2017-07-01 06:37:23
# 3             31.833333           13.833333 2017-07-01 14:30:33
# 4             31.650000           13.833333 2017-07-01 14:46:33
#
#      actual_start_time      exec_start_time
# 0  2017-07-01 06:05:05  2017-07-01 05:41:47
# 1  2017-07-01 06:23:54  2017-07-01 05:41:47
# 2  2017-07-01 06:35:20  2017-07-01 05:41:47
# 3  2017-07-01 14:28:47  2017-07-01 14:09:05
# 4  2017-07-01 14:42:20  2017-07-01 14:09:05

# %%
executed_trips_with_sugestions_matched = matched_otp_legs.select('user_trip_id')\
                                            .drop_duplicates()
printdf(executed_trips_with_sugestions_matched)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-50-d2eeb981c79b> in <module>()
#       1 executed_trips_with_sugestions_matched = matched_otp_legs.select('user_trip_id')                                            .drop_duplicates()
# ----> 2 printdf(executed_trips_with_sugestions_matched)
#
# <ipython-input-2-3e82ea669e49> in printdf(df, l)
#      56
#      57 def printdf(df,l=10):
# ---> 58     return df.limit(l).toPandas()
#      59
#      60 def get_timestamp_in_tz(unixtime_timestamp,ts_format,tz):
#
# /local/tarciso/programs/spark-2.1.0-bin-hadoop2.7/python/pyspark/sql/dataframe.pyc in toPandas(self)
#    1574         """
#    1575         import pandas as pd
# -> 1576         return pd.DataFrame.from_records(self.collect(), columns=self.columns)
#    1577
#    1578     ##########################################################################################
#
# /local/tarciso/programs/spark-2.1.0-bin-hadoop2.7/python/pyspark/sql/dataframe.pyc in collect(self)
#     389         """
#     390         with SCCallSiteSync(self._sc) as css:
# --> 391             port = self._jdf.collectToPython()
#     392         return list(_load_from_socket(port, BatchedSerializer(PickleSerializer())))
#     393
#
# /local/tarciso/programs/spark-2.1.0-bin-hadoop2.7/python/lib/py4j-0.10.4-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
# -> 1133             answer, self.gateway_client, self.target_id, self.name)
#    1134
#    1135         for temp_arg in temp_args:
#
# /local/tarciso/programs/spark-2.1.0-bin-hadoop2.7/python/pyspark/sql/utils.pyc in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /local/tarciso/programs/spark-2.1.0-bin-hadoop2.7/python/lib/py4j-0.10.4-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     317                 raise Py4JJavaError(
#     318                     "An error occurred while calling {0}{1}{2}.\n".
# --> 319                     format(target_id, ".", name), value)
#     320             else:
#     321                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o3264.collectToPython.
# : java.lang.OutOfMemoryError: Java heap space
# 	at java.util.Arrays.copyOf(Arrays.java:3332)
# 	at java.lang.AbstractStringBuilder.ensureCapacityInternal(AbstractStringBuilder.java:124)
# 	at java.lang.AbstractStringBuilder.append(AbstractStringBuilder.java:448)
# 	at java.lang.StringBuilder.append(StringBuilder.java:136)
# 	at java.lang.StringBuilder.append(StringBuilder.java:131)
# 	at scala.StringContext.standardInterpolator(StringContext.scala:125)
# 	at scala.StringContext.s(StringContext.scala:95)
# 	at org.apache.spark.sql.execution.QueryExecution.toString(QueryExecution.scala:225)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:54)
# 	at org.apache.spark.sql.Dataset.withNewExecutionId(Dataset.scala:2765)
# 	at org.apache.spark.sql.Dataset.collectToPython(Dataset.scala:2742)
# 	at sun.reflect.GeneratedMethodAccessor121.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:280)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:214)
# 	at java.lang.Thread.run(Thread.java:745)

# %%
all_trips_alternatives = matched_otp_legs \
                .union(executed_legs) \
                .join(executed_trips_with_sugestions_matched, on='user_trip_id',how='inner') \
                .orderBy(['date','user_trip_id','itinerary_id'])
printdf(all_trips_alternatives)

# %%
all_trips_alternatives.write.csv(path=results_folderpath+'/all_itineraries',header=True)

# %%
print all_trips_alternatives.count(), od_matrix.count(), executed_trips_with_sugestions_matched.count()
# Out:
# 19772 5752 5563

# %%
executed_trips_with_user_plan_matched = matched_executed_trips.select('user_trip_id')\
                                            .drop_duplicates()
printdf(executed_trips_with_sugestions_matched)
# Out:
#    user_trip_id
# 0   42949673263
# 1   68719476787
# 2   94489280644
# 3  300647710918
# 4  455266533408
# 5  455266533670
# 6  472446402873
# 7  498216206460
# 8  558345748598
# 9  644245094648

# %%
all_executed_trips_alternatives = matched_otp_legs \
                .union(executed_legs) \
                .join(executed_trips_with_user_plan_matched, on='user_trip_id',how='inner') \
                .orderBy(['date','user_trip_id','itinerary_id'])
printdf(all_executed_trips_alternatives)
# Out:
#    user_trip_id        date  itinerary_id  planned_duration_mins  \
# 0             7  2017-05-09             0              39.500000
# 1             7  2017-05-09             1              35.416667
# 2             7  2017-05-09             2              35.416667
# 3             7  2017-05-09             3              35.416667
# 4             8  2017-05-09             0              33.833333
# 5             8  2017-05-09             1              38.900000
# 6             8  2017-05-09             2              33.983333
# 7             8  2017-05-09             3              33.983333
# 8             9  2017-05-09             0              23.433333
# 9             9  2017-05-09             1              24.333333
#
#    actual_duration_mins  exec_duration_mins  planned_start_time  \
# 0             29.733333           29.733333 2017-05-09 15:03:44
# 1             30.100000           29.733333 2017-05-09 14:43:19
# 2             25.066667           29.733333 2017-05-09 14:56:19
# 3             25.066667           29.733333 2017-05-09 15:09:19
# 4             28.300000           28.300000 2017-05-09 06:31:38
# 5             34.333333           28.300000 2017-05-09 06:41:51
# 6             35.600000           28.300000 2017-05-09 06:43:38
# 7             44.600000           28.300000 2017-05-09 07:07:38
# 8             21.400000           21.400000 2017-05-09 10:53:34
# 9             24.850000           21.400000 2017-05-09 10:52:51
#
#      actual_start_time      exec_start_time
# 0  2017-05-09 14:40:23  2017-05-09 14:40:23
# 1  2017-05-09 14:40:13  2017-05-09 14:40:23
# 2  2017-05-09 15:07:46  2017-05-09 14:40:23
# 3  2017-05-09 15:07:46  2017-05-09 14:40:23
# 4  2017-05-09 06:32:25  2017-05-09 06:32:25
# 5  2017-05-09 06:41:03  2017-05-09 06:32:25
# 6  2017-05-09 06:49:27  2017-05-09 06:32:25
# 7  2017-05-09 07:07:45  2017-05-09 06:32:25
# 8  2017-05-09 10:44:40  2017-05-09 10:44:40
# 9  2017-05-09 10:54:29  2017-05-09 10:44:40

# %%
print all_executed_trips_alternatives.count(), od_matrix.count(), executed_trips_with_user_plan_matched.count()
# Out:
# 11769 5752 3345

# %%
all_executed_trips_alternatives.write.csv(path=results_folderpath+'/fully_matched_itineraries',header=True)

# %%
printdf(all_trips_alternatives.groupby(['date','user_trip_id']) \
                        .count() \
                        .orderBy('count'))
# Out:
#          date   user_trip_id  count
# 0  2017-05-09   300647710724      2
# 1  2017-05-09  1563368095803      2
# 2  2017-05-09  1245540516041      2
# 3  2017-05-09   412316860483      2
# 4  2017-05-09  1529008357586      2
# 5  2017-05-09   223338299433      2
# 6  2017-05-09  1022202216484      3
# 7  2017-05-09   721554505729      3
# 8  2017-05-09   163208757335      3
# 9  2017-05-09  1700807049484      3

# %%
filtered_trips_alternatives =

# %% [markdown]
# ### Compute Inefficiency Metrics

# %% [markdown]
# #### Given:
# - U - user trip time
# - O - otp suggested trip time
# - E (executed itineraries) = { Ue, {Oie, 0 < i < n, n = num_otp_alt}}
# - P (planned itineraries) = { Up, {Oip, 0 < i < n, n = num_otp_alt}}
#
# #### We can compute:

# %% [markdown]
# $$
# \begin{equation*}
#     \frac{Ue - fastest(E)}{Ue} \text{  User choice actual inefficiency}.
# \end{equation*}
# $$
#
# $$
# \begin{equation*}
#     \frac{fastest(E) - executed(fastest(Oe))}{fastest(E)} \text{ System recommendation inefficiency I}.
# \end{equation*}
# $$
#
# $$
# \begin{equation*}
#     \frac{fastest(E) - fastest(P))}{fastest(E)} \text{ System recommendation inefficiency II}.
# \end{equation*}
# $$
#
# $$
# \begin{equation*}
#     \frac{Up - fastest(P))}{Up} \text{ User choice plan inefficiency}.
# \end{equation*}
# $$
#
# $$
# \begin{equation*}
#     {Oe - Op} \text{ System Schedule Deviation}.
# \end{equation*}
# $$
#
# $$
# \begin{equation*}
#     {Ue - Up} \text{ User Trip Schedule Deviation}.
# \end{equation*}
# $$
#
# $$
# \begin{equation*}
#     {start(Ue) - start(Up)} \text{ User stop waiting time offset}.
# \end{equation*}
# $$

# %%
def filter_trips_alternatives(trips_alternatives):
    min_trip_dur = 10
    max_trip_dur = 50
    max_trip_start_diff = 20
    
    return trips_alternatives[(trips_alternatives['exec_duration_mins'] >= min_trip_dur) & (trips_alternatives['exec_duration_mins'] <= max_trip_dur)] \
                                    .withColumn('start_diff',F.abs(F.unix_timestamp(F.col('exec_start_time')) - F.unix_timestamp(F.col('actual_start_time')))/60) \
                                    .filter('start_diff <= 20')

# %%
#Filter trips whose planned start time is too far away from the executed start time
filtered_trips_itineraries = filter_trips_alternatives(all_trips_alternatives)

# %%
printdf(filtered_trips_itineraries)
# Out:
#          date  user_trip_id  itinerary_id  planned_duration_mins  \
# 0  2017-05-09   25769803948             0                    NaN
# 1  2017-05-09   25769803948             1               7.250000
# 2  2017-05-09   25769803948             2               7.833333
# 3  2017-05-09   51539607858             0                    NaN
# 4  2017-05-09   68719476891             0                    NaN
# 5  2017-05-09   68719476891             1              24.933333
# 6  2017-05-09  111669149831             0                    NaN
# 7  2017-05-09  111669149831             1               9.633333
# 8  2017-05-09  111669149831             2               9.633333
# 9  2017-05-09  137438953719             0                    NaN
#
#    actual_duration_mins  planned_start_time    actual_start_time  \
# 0             15.900000                 NaT  2017-05-09 18:09:17
# 1             15.450000 2017-05-09 18:16:46  2017-05-09 18:21:07
# 2             15.450000 2017-05-09 18:35:29  2017-05-09 18:21:07
# 3             32.983333                 NaT  2017-05-09 13:05:33
# 4             20.133333                 NaT  2017-05-09 18:29:06
# 5             26.683333 2017-05-09 18:35:38  2017-05-09 18:45:08
# 6             13.766667                 NaT  2017-05-09 09:37:41
# 7             14.800000 2017-05-09 09:42:40  2017-05-09 09:36:49
# 8             13.216667 2017-05-09 09:59:40  2017-05-09 09:56:08
# 9             20.000000                 NaT  2017-05-09 14:19:14
#
#    exec_duration_mins      exec_start_time  start_diff
# 0           15.900000  2017-05-09 18:09:17    0.000000
# 1           15.900000  2017-05-09 18:09:17   11.833333
# 2           15.900000  2017-05-09 18:09:17   11.833333
# 3           32.983333  2017-05-09 13:05:33    0.000000
# 4           20.133333  2017-05-09 18:29:06    0.000000
# 5           20.133333  2017-05-09 18:29:06   16.033333
# 6           13.766667  2017-05-09 09:37:41    0.000000
# 7           13.766667  2017-05-09 09:37:41    0.866667
# 8           13.766667  2017-05-09 09:37:41   18.450000
# 9           20.000000  2017-05-09 14:19:14    0.000000

# %% [markdown]
# #### User choice actual inefficiency
#
# $$
# \begin{equation*}
#     \frac{Ue - fastest(E)}{Ue}.
# \end{equation*}
# $$

# %%
#Choose best itinerary for each trip by selecting the ones with lower actual duration
best_trips_itineraries = select_best_trip_itineraries(filtered_trips_itineraries)

# %%
printdf(best_trips_itineraries)
# Out:
#          date   user_trip_id  itinerary_id  planned_duration_mins  \
# 0  2017-05-09   515396075621             0                    NaN
# 1  2017-05-09   163208757335             3               3.800000
# 2  2017-05-09   790273982609             2              24.816667
# 3  2017-05-09  1700807049484             0                    NaN
# 4  2017-05-09   721554505729             1               6.616667
# 5  2017-05-09   489626271850             0                    NaN
# 6  2017-05-09    25769803948             2               7.833333
# 7  2017-05-09  1443109011501             0                    NaN
# 8  2017-05-09  1005022347340             0                    NaN
# 9  2017-05-09  1194000908297             3               6.150000
#
#    actual_duration_mins  planned_start_time    actual_start_time  \
# 0             17.083333                 NaT  2017-05-09 07:38:27
# 1              4.266667 2017-05-09 08:41:52  2017-05-09 08:36:39
# 2             20.033333 2017-05-09 07:24:43  2017-05-09 07:26:59
# 3             14.933333                 NaT  2017-05-09 17:39:37
# 4              6.466667 2017-05-09 10:04:00  2017-05-09 10:12:19
# 5             12.316667                 NaT  2017-05-09 13:27:40
# 6             15.450000 2017-05-09 18:35:29  2017-05-09 18:21:07
# 7             17.166667                 NaT  2017-05-09 05:22:54
# 8             11.116667                 NaT  2017-05-09 17:57:17
# 9              6.366667 2017-05-09 06:57:27  2017-05-09 07:04:51
#
#    exec_duration_mins      exec_start_time  start_diff
# 0           17.083333  2017-05-09 07:38:27    0.000000
# 1           27.166667  2017-05-09 08:37:33    0.900000
# 2           33.516667  2017-05-09 07:10:50   16.150000
# 3           14.933333  2017-05-09 17:39:37    0.000000
# 4           43.100000  2017-05-09 10:02:29    9.833333
# 5           12.316667  2017-05-09 13:27:40    0.000000
# 6           15.900000  2017-05-09 18:09:17   11.833333
# 7           17.166667  2017-05-09 05:22:54    0.000000
# 8           11.116667  2017-05-09 17:57:17    0.000000
# 9           36.733333  2017-05-09 06:48:22   16.483333

# %%
trips_inefficiency = best_trips_itineraries \
                        .withColumn('dur_diff',(F.col('exec_duration_mins') - F.col('actual_duration_mins'))) \
                        .withColumn('imp_capacity', F.col('dur_diff')/F.col('exec_duration_mins'))

# %%
printdf(trips_inefficiency)
# Out:
#          date   user_trip_id  itinerary_id  planned_duration_mins  \
# 0  2017-05-09   515396075621             0                    NaN
# 1  2017-05-09   163208757335             3               3.800000
# 2  2017-05-09   790273982609             2              24.816667
# 3  2017-05-09  1700807049484             0                    NaN
# 4  2017-05-09   721554505729             1               6.616667
# 5  2017-05-09   489626271850             0                    NaN
# 6  2017-05-09    25769803948             2               7.833333
# 7  2017-05-09  1443109011501             0                    NaN
# 8  2017-05-09  1005022347340             0                    NaN
# 9  2017-05-09  1194000908297             3               6.150000
#
#    actual_duration_mins  planned_start_time    actual_start_time  \
# 0             17.083333                 NaT  2017-05-09 07:38:27
# 1              4.266667 2017-05-09 08:41:52  2017-05-09 08:36:39
# 2             20.033333 2017-05-09 07:24:43  2017-05-09 07:26:59
# 3             14.933333                 NaT  2017-05-09 17:39:37
# 4              6.466667 2017-05-09 10:04:00  2017-05-09 10:12:19
# 5             12.316667                 NaT  2017-05-09 13:27:40
# 6             15.450000 2017-05-09 18:35:29  2017-05-09 18:21:07
# 7             17.166667                 NaT  2017-05-09 05:22:54
# 8             11.116667                 NaT  2017-05-09 17:57:17
# 9              6.366667 2017-05-09 06:57:27  2017-05-09 07:04:51
#
#    exec_duration_mins      exec_start_time  start_diff   dur_diff  \
# 0           17.083333  2017-05-09 07:38:27    0.000000   0.000000
# 1           27.166667  2017-05-09 08:37:33    0.900000  22.900000
# 2           33.516667  2017-05-09 07:10:50   16.150000  13.483333
# 3           14.933333  2017-05-09 17:39:37    0.000000   0.000000
# 4           43.100000  2017-05-09 10:02:29    9.833333  36.633333
# 5           12.316667  2017-05-09 13:27:40    0.000000   0.000000
# 6           15.900000  2017-05-09 18:09:17   11.833333   0.450000
# 7           17.166667  2017-05-09 05:22:54    0.000000   0.000000
# 8           11.116667  2017-05-09 17:57:17    0.000000   0.000000
# 9           36.733333  2017-05-09 06:48:22   16.483333  30.366667
#
#    imp_capacity
# 0      0.000000
# 1      0.842945
# 2      0.402287
# 3      0.000000
# 4      0.849961
# 5      0.000000
# 6      0.028302
# 7      0.000000
# 8      0.000000
# 9      0.826679

# %% [markdown]
# #### System Recommendation Inefficiency I
# $$
# \begin{equation*}
#     \frac{fastest(E) - executed(fastest(Oe))}{fastest(E)}
# \end{equation*}
# $$

# %%
w_rec_inef_i = Window().partitionBy(['date','user_trip_id']).orderBy(F.col('planned_duration_mins'))

shortest_planned_actual_duration = filtered_trips_itineraries \
                            .filter('itinerary_id > 0') \
                            .withColumn("rn", F.row_number().over(w_rec_inef_i)) \
                            .where(F.col("rn") == 1) \
                            .select('date','user_trip_id','planned_duration_mins','actual_duration_mins') \
                            .withColumnRenamed('planned_duration_mins','shortest_OTP_planned_duration') \
                            .withColumnRenamed('actual_duration_mins','shortest_OTP_actual_duration')

printdf(shortest_planned_actual_duration)
# Out:
#          date   user_trip_id  shortest_OTP_planned_duration  \
# 0  2017-05-09   515396075621                      17.566667
# 1  2017-05-09   163208757335                       3.800000
# 2  2017-05-09   790273982609                      24.600000
# 3  2017-05-09  1700807049484                      17.300000
# 4  2017-05-09   721554505729                       6.616667
# 5  2017-05-09   489626271850                      12.966667
# 6  2017-05-09    25769803948                       7.250000
# 7  2017-05-09  1443109011501                      26.483333
# 8  2017-05-09  1005022347340                      14.700000
# 9  2017-05-09  1194000908297                       6.150000
#
#    shortest_OTP_actual_duration
# 0                     17.250000
# 1                      4.266667
# 2                     21.666667
# 3                     26.100000
# 4                      6.466667
# 5                     12.983333
# 6                     15.450000
# 7                     17.966667
# 8                     11.650000
# 9                      6.366667

# %%
rec_inef_i = filtered_trips_itineraries \
                .groupBy(['date','user_trip_id']) \
                .agg(F.min(F.col('actual_duration_mins')).alias('shortest_actual_duration')) \
                .join(shortest_planned_actual_duration, on=['date','user_trip_id'], how='inner') \
                .withColumn('rec_inef',(F.col('shortest_OTP_actual_duration') - F.col('shortest_actual_duration'))/F.col('shortest_OTP_actual_duration'))

printdf(rec_inef_i_features)
# Out:
#          date   user_trip_id  shortest_actual_duration  \
# 0  2017-05-09   515396075621                 17.083333
# 1  2017-05-09   163208757335                  4.266667
# 2  2017-05-09   790273982609                 20.033333
# 3  2017-05-09  1700807049484                 14.933333
# 4  2017-05-09   721554505729                  6.466667
# 5  2017-05-09   489626271850                 12.316667
# 6  2017-05-09    25769803948                 15.450000
# 7  2017-05-09  1443109011501                 17.166667
# 8  2017-05-09  1005022347340                 11.116667
# 9  2017-05-09  1194000908297                  6.366667
#
#    shortest_planned_OTP_duration  rec_inef
# 0                      17.566667 -0.028293
# 1                       3.800000  0.109375
# 2                      24.600000 -0.227953
# 3                      17.300000 -0.158482
# 4                       6.616667 -0.023196
# 5                      12.966667 -0.052774
# 6                       7.250000  0.530744
# 7                      26.483333 -0.542718
# 8                      14.700000 -0.322339
# 9                       6.150000  0.034031

# %% [markdown]
# #### System Recommendation Inefficiency II
# $$
# \begin{equation*}
#     \frac{fastest(E) - fastest(P))}{fastest(E)}
# \end{equation*}
# $$

# %% [markdown]
# #### User choice plan inefficiency
# $$
# \begin{equation*}
#     \frac{Up - fastest(P))}{Up}
# \end{equation*}
# $$

# %% [markdown]
# #### System Schedule Deviation
# $$
# \begin{equation*}
#     {Oe - Op}
# \end{equation*}
# $$

# %% [markdown]
# #### User Trip Schedule Deviation
# $$
# \begin{equation*}
#     {Ue - Up}
# \end{equation*}
# $$

# %% [markdown]
# #### User stop waiting time offset
# $$
# \begin{equation*}
#     {start(Ue) - start(Up)}
# \end{equation*}
# $$

# %%
print "Identifying itinerary alternatives which are feasible..."
trips_itineraries_possibilities, filtered_trips_possibilities = determining_trips_alternatives_feasibility(clean_legs_actual_time,od_matrix)
# Out:
# Identifying itinerary alternatives which are feasible...

# %%
printdf(od_matrix.select('date'))
# Out:
#          date
# 0  2017-05-09
# 1  2017-05-09
# 2  2017-05-09
# 3  2017-05-09
# 4  2017-05-09
# 5  2017-05-09
# 6  2017-05-09
# 7  2017-05-09
# 8  2017-05-09
# 9  2017-05-09

# %%
printdf(trips_itineraries_possibilities)
# Out:
#          date  user_trip_id  itinerary_id   duration       alt_start_time  \
# 0  2017-05-09   25769803948             1  15.450000  2017-05-09 18:16:42
# 1  2017-05-09   25769803948             2  15.450000  2017-05-09 18:42:57
# 2  2017-05-09   51539607858             1  42.383333  2017-05-09 13:29:50
# 3  2017-05-09   51539607858             2  31.666667  2017-05-09 13:53:20
# 4  2017-05-09   51539607858             3  32.333333  2017-05-09 14:59:28
# 5  2017-05-09   68719476891             1  26.683333  2017-05-09 18:45:08
# 6  2017-05-09   68719476891             2  26.266667  2017-05-09 18:57:18
# 7  2017-05-09   68719476891             3  20.750000  2017-05-09 18:50:04
# 8  2017-05-09  111669149831             1  14.800000  2017-05-09 09:42:32
# 9  2017-05-09  111669149831             2  13.216667  2017-05-09 10:09:09
#
#        exec_start_time  start_diff
# 0  2017-05-09 18:09:17    7.416667
# 1  2017-05-09 18:09:17   33.666667
# 2  2017-05-09 13:05:33   24.283333
# 3  2017-05-09 13:05:33   47.783333
# 4  2017-05-09 13:05:33  113.916667
# 5  2017-05-09 18:29:06   16.033333
# 6  2017-05-09 18:29:06   28.200000
# 7  2017-05-09 18:29:06   20.966667
# 8  2017-05-09 09:37:41    4.850000
# 9  2017-05-09 09:37:41   31.466667

# %%
printdf(filtered_trips_possibilities)
# Out:
#          date  user_trip_id  itinerary_id   duration       alt_start_time
# 0  2017-05-09   25769803948             1  15.450000  2017-05-09 18:16:42
# 1  2017-05-09   68719476891             1  26.683333  2017-05-09 18:45:08
# 2  2017-05-09  111669149831             1  14.800000  2017-05-09 09:42:32
# 3  2017-05-09  111669149962             1  47.516667  2017-05-09 17:53:38
# 4  2017-05-09  111669149962             2  39.266667  2017-05-09 18:10:19
# 5  2017-05-09  120259084497             1   4.833333  2017-05-09 13:13:57
# 6  2017-05-09  120259084497             2   3.966667  2017-05-09 13:25:17
# 7  2017-05-09  120259084497             3   3.750000  2017-05-09 13:30:06
# 8  2017-05-09  137438953719             1  31.333333  2017-05-09 14:34:35
# 9  2017-05-09  163208757335             1   4.016667  2017-05-09 08:35:33

# %%
print "Writing itineraries possibilities with feasibility to file..."
#trips_itineraries_possibilities.write.csv(path=results_folderpath+'/itineraries_alternatives',header=True, mode='append')
# Out:
# Writing itineraries possibilities with feasibility to file...

# %%
print "Adding executed trips to the pool of itinerary possibilities..."
trips_itineraries_pool = get_trips_itineraries_pool(filtered_trips_possibilities,od_matrix)
# Out:
# Adding executed trips to the pool of itinerary possibilities...

# %%
printdf(trips_itineraries_pool,l=10)
# Out:
#          date  user_trip_id  itinerary_id   duration       alt_start_time
# 0  2017-05-09   25769803948             0  15.900000  2017-05-09 18:09:17
# 1  2017-05-09   25769803948             1  15.450000  2017-05-09 18:16:42
# 2  2017-05-09   51539607858             0  32.983333  2017-05-09 13:05:33
# 3  2017-05-09   68719476891             0  20.133333  2017-05-09 18:29:06
# 4  2017-05-09   68719476891             1  26.683333  2017-05-09 18:45:08
# 5  2017-05-09  111669149831             0  13.766667  2017-05-09 09:37:41
# 6  2017-05-09  111669149831             1  14.800000  2017-05-09 09:42:32
# 7  2017-05-09  111669149962             0  61.233333  2017-05-09 17:54:34
# 8  2017-05-09  111669149962             1  47.516667  2017-05-09 17:53:38
# 9  2017-05-09  111669149962             2  39.266667  2017-05-09 18:10:19

# %%
print "Selecting best otp itineraries by actual duration..."
best_trips_itineraries = select_best_trip_itineraries(trips_itineraries_pool)
# Out:
# Selecting best otp itineraries by actual duration...

# %%
printdf(best_trips_itineraries,l=20)
# Out:
#           date   user_trip_id  itinerary_id   duration       alt_start_time
# 0   2017-05-09   515396075621             0  17.083333  2017-05-09 07:38:27
# 1   2017-05-09   206158430497             0   4.750000  2017-05-09 16:41:46
# 2   2017-05-09  1022202216484             0   1.533333  2017-05-09 06:44:51
# 3   2017-05-09   163208757335             1   4.016667  2017-05-09 08:35:33
# 4   2017-05-09   790273982609             2  20.033333  2017-05-09 07:22:11
# 5   2017-05-09  1700807049484             0  14.933333  2017-05-09 17:39:37
# 6   2017-05-09   412316860483             1   5.633333  2017-05-09 11:57:46
# 7   2017-05-09   721554505729             1   6.466667  2017-05-09 10:02:15
# 8   2017-05-09   489626271850             0  12.316667  2017-05-09 13:27:40
# 9   2017-05-09    25769803948             1  15.450000  2017-05-09 18:16:42
# 10  2017-05-09  1013612282175             0   9.450000  2017-05-09 15:18:36
# 11  2017-05-09  1443109011501             0  17.166667  2017-05-09 05:22:54
# 12  2017-05-09  1417339207791             3   6.483333  2017-05-09 17:04:31
# 13  2017-05-09  1391569403990             0   1.383333  2017-05-09 13:04:17
# 14  2017-05-09   257698037870             0   2.600000  2017-05-09 09:59:50
# 15  2017-05-09  1005022347340             0  11.116667  2017-05-09 17:57:17
# 16  2017-05-09  1194000908297             3   6.366667  2017-05-09 06:54:26
# 17  2017-05-09   137438953719             0  20.000000  2017-05-09 14:19:14
# 18  2017-05-09   824633721011             3  17.233333  2017-05-09 17:47:29
# 19  2017-05-09   781684047908             3  27.533333  2017-05-09 08:46:53

# %%
#Clean Memory
#clean_legs_actual_time.unpersist(blocking=True)
#trips_itineraries_possibilities.unpersist(blocking=True)
#filtered_trips_possibilities.unpersist(blocking=True)
#trips_itineraries_pool.unpersist(blocking=True)

# %%
printdf(duration_improvement_capacity)
# Out:
#          date   user_trip_id   cardNum birthdate gender      exec_start_time  \
# 0  2017-05-09   515396075621   2642531  28/09/95      F  2017-05-09 07:38:27
# 1  2017-05-09   206158430497   1757419      None   None  2017-05-09 16:41:46
# 2  2017-05-09  1022202216484  10090017      None   None  2017-05-09 06:44:51
# 3  2017-05-09   163208757335   2782068      None   None  2017-05-09 08:37:33
# 4  2017-05-09   790273982609   3645964      None   None  2017-05-09 07:10:50
# 5  2017-05-09  1700807049484   2658794  30/03/78      M  2017-05-09 17:39:37
# 6  2017-05-09   412316860483   3541708      None   None  2017-05-09 11:59:46
# 7  2017-05-09   721554505729    643873      None   None  2017-05-09 10:02:29
# 8  2017-05-09   489626271850   3709654      None   None  2017-05-09 13:27:40
# 9  2017-05-09    25769803948   3377631  21/06/00      F  2017-05-09 18:09:17
#
#    executed_duration  itinerary_id   duration       alt_start_time  \
# 0          17.083333             0  17.083333  2017-05-09 07:38:27
# 1           4.750000             0   4.750000  2017-05-09 16:41:46
# 2           1.533333             0   1.533333  2017-05-09 06:44:51
# 3          27.166667             1   4.016667  2017-05-09 08:35:33
# 4          33.516667             2  20.033333  2017-05-09 07:22:11
# 5          14.933333             0  14.933333  2017-05-09 17:39:37
# 6          65.033333             1   5.633333  2017-05-09 11:57:46
# 7          43.100000             1   6.466667  2017-05-09 10:02:15
# 8          12.316667             0  12.316667  2017-05-09 13:27:40
# 9          15.900000             1  15.450000  2017-05-09 18:16:42
#
#    imp_capacity
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3     23.150000
# 4     13.483333
# 5      0.000000
# 6     59.400000
# 7     36.633333
# 8      0.000000
# 9      0.450000

# %%
print "Computing Improvement Capacity..."
duration_improvement_capacity = compute_improvement_capacity(best_trips_itineraries,od_matrix)
# Out:
# Computing Improvement Capacity...

# %%
#best_trips_itineraries.unpersist(blocking=True)
#od_matrix.unpersist(blocking=True)

# %%
print "Writing duration improvement capacity to file..."
#duration_improvement_capacity.write.csv(path=results_folderpath+'/duration_improvement_capacity',header=True, mode='append')

# %%
print "Finishing Script..."

# %%
sc.stop()
