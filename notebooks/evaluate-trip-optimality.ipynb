# %%
import pandas as pd
import numpy as np
import urllib2
import json
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-143-339051949b4f> in <module>()
# ----> 1 import pyspark
#       2
#       3 import pandas as pd
#       4 import numpy as np
#       5 import urllib2
#
# ImportError: No module named pyspark

# %%
od_matrix = pd.read_csv('od_matrix_05_11_2017.csv')

# %%
od_matrix.columns
# Out:
# Index([u'route', u'tripNum', u'shapeId', u'shapeSequence', u'shapeLat',
#        u'shapeLon', u'distanceTraveledShape', u'busCode', u'gpsPointId',
#        u'gpsLat', u'gpsLon', u'distanceToShapePoint', u'timestamp',
#        u'stopPointId', u'problem', u'birthdate', u'cardTimestamp', u'lineName',
#        u'gender', u'date', u'id', u'o_route', u'o_bus_code', u'o_date',
#        u'o_tripNum', u'o_timestamp', u'o_shape_id', u'o_shape_seq',
#        u'o_shape_lat', u'o_shape_lon', u'o_stop_id', u'o_boarding_id',
#        u'cardNum', u'next_o_route', u'next_o_bus_code', u'next_o_date',
#        u'next_o_tripNum', u'next_o_timestamp', u'next_o_shape_id',
#        u'next_o_shape_seq', u'next_o_shape_lat', u'next_o_shape_lon',
#        u'next_o_stop_id', u'next_o_boarding_id', u'o_unixtimestamp',
#        u'next_o_unixtimestamp', u'leg_duration', u'dist', u'rn'],
#       dtype='object')

# %%
od_matrix.head()
# Out:
#    route  tripNum  shapeId  shapeSequence   shapeLat   shapeLon  \
# 0    374        2     1895        5950316 -25.428322 -49.266739
# 1     50        1     1719        5305699 -25.450914 -49.226300
# 2    967       13     2286        6087787 -25.426956 -49.279220
# 3    535        3     1979        6393158 -25.552426 -49.254353
# 4    463        8     1915        6348024 -25.431822 -49.267690
#
#    distanceTraveledShape busCode  gpsPointId     gpsLat ...  next_o_shape_seq  \
# 0               9309.107   CC171         NaN -25.428408 ...           4870329
# 1              14546.742   DR103         NaN -25.450981 ...           5304613
# 2               1195.869   MC861         NaN -25.426836 ...           6086302
# 3                  0.000   EA600         NaN -25.552370 ...           6403979
# 4                274.616   DC087         NaN        NaN ...           5386363
#
#    next_o_shape_lat next_o_shape_lon  next_o_stop_id next_o_boarding_id  \
# 0        -25.433636       -49.272494           26373      1262720385064
# 1        -25.450921       -49.226295           32410       377957122168
# 2        -25.426275       -49.277075           33734      1571958030378
# 3        -25.550383       -49.261133           31258      1382979469425
# 4        -25.430770       -49.276242           29420       609885356066
#
#   o_unixtimestamp next_o_unixtimestamp leg_duration      dist rn
# 0           37193                63950   445.950000  0.826454  1
# 1           35939                66247   505.133333  0.000920  1
# 2           61513                46571    -1.000000  0.228346  1
# 3           37652                56596   315.733333  0.717050  1
# 4           55623                37323    -1.000000  0.866776  1
#
# [5 rows x 49 columns]

# %%
od_matrix['o_datetime'] = pd.to_datetime(od_matrix['date'] + ' ' + od_matrix['o_timestamp'])

# %%
od_matrix['o_base_timestamp'] = (od_matrix['o_datetime'] - pd.Timedelta('2 min')).dt.strftime('%H:%M:%S')

# %%
od_matrix[['o_datetime','o_base_timestamp']].head()
# Out:
#            o_datetime o_base_timestamp
# 0 2017-05-10 07:19:53         07:17:53
# 1 2017-05-10 06:58:59         06:56:59
# 2 2017-05-10 14:05:13         14:03:13
# 3 2017-05-10 07:27:32         07:25:32
# 4 2017-05-10 12:27:03         12:25:03

# %%
simple_od_matrix = od_matrix[['date','route','o_stop_id','o_timestamp','o_shape_lat','o_shape_lon','stopPointId','timestamp','shapeLat','shapeLon']]

# %%
simple_od_matrix.head()
# Out:
#          date  route  o_stop_id o_timestamp  o_shape_lat  o_shape_lon  \
# 0  2017-05-10    374      31957    07:19:53   -25.413083   -49.229020
# 1  2017-05-10     50      31740    06:58:59   -25.475134   -49.299069
# 2  2017-05-10    967      26345    14:05:13   -25.429278   -49.271228
# 3  2017-05-10    535      36880    07:27:32   -25.554885   -49.255697
# 4  2017-05-10    463      26340    12:27:03   -25.432775   -49.270209
#
#    stopPointId timestamp   shapeLat   shapeLon
# 0        26362  07:41:47 -25.428322 -49.266739
# 1        31769  07:32:13 -25.450914 -49.226300
# 2        26722  14:07:44 -25.426956 -49.279220
# 3         4664  08:06:00 -25.552426 -49.254353
# 4        29922  12:34:16 -25.431822 -49.267690

# %%
otp_server_url = 'http://localhost:5601/otp/'
otp_http_request = 'routers/ctba/plan?fromPlace={},{}&toPlace={},{}&mode=TRANSIT,WALK&date={}&time={}'
def get_otp_itineraries(o_lat,o_lon,d_lat,d_lon,date,time):
    otp_request_url = otp_server_url + otp_http_request.format(o_lat,o_lon,d_lat,d_lon,date,time)
    return json.loads(urllib2.urlopen(otp_request_url).read())

# %%
test_itinerary = get_otp_itineraries(-25.413083,-49.229020,-25.428322,-49.266739,'05-10-2017','7:19:00')

print test_itinerary
# Out:
# {u'elevationMetadata': {u'geoidElevation': False, u'ellipsoidToGeoidDifference': 3.686111287840708}, u'plan': {u'date': 1494411540000, u'to': {u'lat': -25.428322, u'vertexType': u'NORMAL', u'lon': -49.266739, u'name': u'Destination', u'orig': u''}, u'itineraries': [{u'walkTime': 2, u'legs': [{u'distance': 0.151, u'from': {u'vertexType': u'NORMAL', u'name': u'Origin', u'lon': -49.22902, u'departure': 1494411566000, u'lat': -25.413083, u'orig': u''}, u'interlineWithPreviousLeg': False, u'transitLeg': False, u'realTime': False, u'route': u'', u'departureDelay': 0, u'agencyTimeZoneOffset': -10800000, u'to': {u'arrival': 1494411567000, u'vertexType': u'TRANSIT', u'name': u'Rua Fagundes Varela, 1295 - Jardim Social', u'stopSequence': 12, u'lon': -49.229029895014, u'departure': 1494411568000, u'stopId': u'1:31957', u'stopCode': u'130279', u'lat': -25.413059468751, u'stopIndex': 11}, u'rentedBike': False, u'arrivalDelay': 0, u'mode': u'WALK', u'startTime': 1494411566000, u'duration': 1.0, u'steps': [{u'distance': 0.151, u'relativeDirection': u'DEPART', u'elevation': [], u'area': False, u'lon': -49.228999194272866, u'stayOn': False, u'absoluteDirection': u'NORTHEAST', u'lat': -25.413125419855316, u'bogusName': False, u'streetName': u'Rua Fagundes Varela'}], u'endTime': 1494411567000, u'pathway': False, u'legGeometry': {u'length': 2, u'points': u'`obzCf`nkH??'}}, {u'transitLeg': True, u'realTime': False, u'headsign': u'Pra\xe7a Santos Andrade', u'routeLongName': u'HUGO LANGE', u'duration': 1352.0, u'rentedBike': False, u'routeShortName': u'374', u'tripId': u'1:3872197', u'agencyUrl': u'http://www.urbs.curitiba.pr.gov.br', u'routeColor': u'EFDC07', u'routeId': u'1:102', u'to': {u'arrival': 1494412920000, u'vertexType': u'TRANSIT', u'name': u'Pra\xe7a Santos Andrade - 374 - Hugo Lange', u'stopSequence': 32, u'lon': -49.266673357433, u'departure': 1494412921000, u'stopId': u'1:26362', u'stopCode': u'103403', u'lat': -25.42845547217, u'stopIndex': 31}, u'arrivalDelay': 0, u'serviceDate': u'20170510', u'pathway': False, u'interlineWithPreviousLeg': False, u'agencyId': u'1', u'departureDelay': 0, u'startTime': 1494411568000, u'from': {u'arrival': 1494411567000, u'vertexType': u'TRANSIT', u'name': u'Rua Fagundes Varela, 1295 - Jardim Social', u'stopSequence': 12, u'lon': -49.229029895014, u'departure': 1494411568000, u'stopId': u'1:31957', u'stopCode': u'130279', u'lat': -25.413059468751, u'stopIndex': 11}, u'agencyTimeZoneOffset': -10800000, u'routeType': 3, u'distance': 4943.078021673666, u'agencyName': u'URBS', u'route': u'374', u'legGeometry': {u'length': 156, u'points': u'xnbzCj`nkH?@x@jCr@|Br@|Bn@vBN`@x@jCXbA`A~CHTL`@j@fBxAxE^pADHb@vAd@zAx@nCLb@l@rBl@tB^nAVx@J^h@jBl@xBDj@CfAEfAMzCIxBEfAC`@Cr@KxBKtCKhCEjAAb@KzBIbCGrAMlDItBAj@Ev@GdBCz@Ct@SrEE~ACx@IzCA`BCpBw@jASVYb@]d@CDy@lAJlB@JHhAJdBHhADA@?D@@D@D?B@BADABADdBf@h@J^LPFHBf@Pd@Pp@Vn@VVJXJv@Xp@RHBlA\\|@XTDZPl@p@`@d@b@`@f@f@Z^b@b@r@r@bA]`A]j@QLGfC{@fBo@pBo@RINEb@O^OJEb@OlBo@RGp@Sx@Wp@SPGHIBTLd@XhA^pAv@tC?@Rp@fA~D|@hCNd@@BN`@^vAx@zCf@`Bl@nBj@vBz@dDPn@n@pBe@Xo@TUJg@N{@Z?m@Ai@AUCi@Cg@COGYK]Qi@'}, u'steps': [], u'mode': u'BUS', u'endTime': 1494412920000, u'routeTextColor': u'000000'}, {u'distance': 0.182, u'from': {u'arrival': 1494412920000, u'vertexType': u'TRANSIT', u'name': u'Pra\xe7a Santos Andrade - 374 - Hugo Lange', u'stopSequence': 32, u'lon': -49.266673357433, u'departure': 1494412921000, u'stopId': u'1:26362', u'stopCode': u'103403', u'lat': -25.42845547217, u'stopIndex': 31}, u'interlineWithPreviousLeg': False, u'transitLeg': False, u'realTime': False, u'route': u'', u'departureDelay': 0, u'agencyTimeZoneOffset': -10800000, u'to': {u'arrival': 1494412922000, u'vertexType': u'NORMAL', u'name': u'Destination', u'lon': -49.266739, u'lat': -25.428322, u'orig': u''}, u'rentedBike': False, u'arrivalDelay': 0, u'mode': u'WALK', u'startTime': 1494412921000, u'duration': 1.0, u'steps': [{u'distance': 0.182, u'relativeDirection': u'DEPART', u'elevation': [], u'area': False, u'lon': -49.26672630316 ...

# %%
#simple_od_matrix.loc[:,'itineraries'] = simple_od_matrix.apply(
#    lambda row: get_otp_itineraries(row['o_shape_lat'], row['o_shape_lon'], row['shapeLat'], row['shapeLon'],row['date'],row['o_timestamp']), axis=1)

# %%
#simple_od_matrix.head()

# %% [markdown]
# ### New Approach

# %%
trips_otp_response = {}
counter = 0
for index, row in od_matrix[:10].iterrows():
        id=long(row['o_boarding_id'])
        trip_plan = get_otp_itineraries(row['o_shape_lat'], row['o_shape_lon'], row['shapeLat'], row['shapeLon'],row['date'],row['o_base_timestamp'])
        trips_otp_response[id] = trip_plan
        counter+=1

# %%
trips_plans = []

for trip in trips_otp_response.keys():
    itinerary_id = 1
    for itinerary in trips_otp_response[trip]['plan']['itineraries']:
        leg_id = 1
        for leg in itinerary['legs']:
            route = leg['route'] if leg['route'] != '' else None
            fromStopId = leg['from']['stopId'].split(':')[1] if leg['mode'] == 'BUS' else None
            toStopId = leg['to']['stopId'].split(':')[1] if leg['mode'] == 'BUS' else None
            start_time = pd.to_datetime(long(leg['startTime']),unit='ms').tz_localize('UTC').tz_convert('America/Sao_Paulo')
            end_time = pd.to_datetime(long(leg['endTime']),unit='ms').tz_localize('UTC').tz_convert('America/Sao_Paulo')
            duration = end_time - start_time
            date_str = start_time.strftime('%Y-%m-%d')
            start_time_str = start_time.strftime('%H:%M:%S')
            end_time_str = end_time.strftime('%H:%M:%S')
            trips_plans.append((date_str,trip,itinerary_id,leg_id,start_time_str,end_time_str,leg['mode'],route,fromStopId,toStopId, duration))
            leg_id += 1
        itinerary_id += 1

labels=['date','trip_id','itinerary_id','leg_id','start_time','end_time','mode','route','from_stop_id','to_stop_id','duration']
trips_plans_df = pd.DataFrame.from_records(trips_plans,columns=labels)
trips_plans_df['route'] = trips_plans_df['route'].astype(float)
trips_plans_df['from_stop_id'] = trips_plans_df['from_stop_id'].astype(float)
trips_plans_df['to_stop_id'] = trips_plans_df['to_stop_id'].astype(float)

# %%
trips_plans_df
# Out:
#           date        trip_id  itinerary_id  leg_id start_time  end_time  \
# 0   2017-05-10  1434519077089             1       1   07:19:26  07:19:27
# 1   2017-05-10  1434519077089             1       2   07:19:28  07:42:00
# 2   2017-05-10  1434519077089             1       3   07:42:01  07:42:02
# 3   2017-05-10  1434519077089             2       1   07:27:14  07:27:15
# 4   2017-05-10  1434519077089             2       2   07:27:16  07:48:00
# 5   2017-05-10  1434519077089             2       3   07:48:01  07:48:17
# 6   2017-05-10  1434519077089             3       1   07:35:11  07:35:12
# 7   2017-05-10  1434519077089             3       2   07:35:13  07:59:00
# 8   2017-05-10  1434519077089             3       3   07:59:01  07:59:02
# 9   2017-05-10   249108103395             1       1   16:36:21  16:36:32
# 10  2017-05-10   249108103395             1       2   16:36:33  17:28:00
# 11  2017-05-10   249108103395             1       3   17:28:01  17:28:02
# 12  2017-05-10   249108103395             2       1   16:58:27  16:58:38
# 13  2017-05-10   249108103395             2       2   16:58:39  17:43:00
# 14  2017-05-10   249108103395             2       3   17:43:01  17:43:02
# 15  2017-05-10   249108103395             3       1   17:13:27  17:13:38
# 16  2017-05-10   249108103395             3       2   17:13:39  17:58:00
# 17  2017-05-10   249108103395             3       3   17:58:01  17:58:02
# 18  2017-05-10   953482739750             1       1   16:47:05  16:48:18
# 19  2017-05-10   953482739750             1       2   16:48:19  17:16:39
# 20  2017-05-10   953482739750             1       3   17:16:40  17:16:48
# 21  2017-05-10   953482739750             2       1   17:28:05  17:29:18
# 22  2017-05-10   953482739750             2       2   17:29:19  17:53:14
# 23  2017-05-10   953482739750             2       3   17:53:15  17:53:23
# 24  2017-05-10   953482739750             3       1   18:02:05  18:03:18
# 25  2017-05-10   953482739750             3       2   18:03:19  18:27:14
# 26  2017-05-10   953482739750             3       3   18:27:15  18:27:23
# 27  2017-05-10   876173328641             1       1   12:25:03  12:28:36
# 28  2017-05-10   876173328641             2       1   12:25:59  12:26:49
# 29  2017-05-10   876173328641             2       2   12:26:50  12:28:25
# ..         ...            ...           ...     ...        ...       ...
# 54  2017-05-10   584115552472             2       2   18:37:11  18:50:13
# 55  2017-05-10   584115552472             2       3   18:50:14  18:50:21
# 56  2017-05-10   584115552472             3       1   18:41:42  18:41:47
# 57  2017-05-10   584115552472             3       2   18:41:48  18:59:39
# 58  2017-05-10   584115552472             3       3   18:59:40  18:59:47
# 59  2017-05-10  1700807049337             1       1   07:01:29  07:01:47
# 60  2017-05-10  1700807049337             1       2   07:01:48  07:41:09
# 61  2017-05-10  1700807049337             1       3   07:41:10  07:41:31
# 62  2017-05-10  1700807049337             2       1   07:19:35  07:19:53
# 63  2017-05-10  1700807049337             2       2   07:19:54  08:00:03
# 64  2017-05-10  1700807049337             2       3   08:00:04  08:00:25
# 65  2017-05-10  1700807049337             3       1   07:30:24  07:30:42
# 66  2017-05-10  1700807049337             3       2   07:30:43  08:10:13
# 67  2017-05-10  1700807049337             3       3   08:10:14  08:10:35
# 68  2017-05-10   549755813950             1       1   14:06:53  14:10:59
# 69  2017-05-10   549755813950             1       2   14:11:00  14:13:53
# 70  2017-05-10   549755813950             1       3   14:13:54  14:13:55
# 71  2017-05-10   549755813950             2       1   14:10:43  14:14:59
# 72  2017-05-10   549755813950             2       2   14:15:00  14:17:53
# 73  2017-05-10   549755813950             2       3   14:17:54  14:17:55
# 74  2017-05-10   549755813950             3       1   14:15:14  14:16:59
# 75  2017-05-10   549755813950             3       2   14:17:00  14:21:03
# 76  2017-05-10   549755813950             3       3   14:21:04  14:21:05
# 77  2017-05-10  1477468749951             1       1   17:09:40  17:25:18
# 78  2017-05-10  1477468749951             2       1   17:36:24  17:38:59
# 79  2017-05-10  1477468749951             2       2   17:39:00  17:44:47
# 80  2017-05-10  1477468749951             2       3   17:44:48  17:45:14
# 81  2017-05-10  1477468749951             3       1   17:53:19  17:53:59
# 82  2017-05-10  1477468749951             3       2   17:54:00  17:55:57
# 83  2017-05-10  1477468749951             3       3   17:55:58  18:03:22
#
#     mode  route  from_stop_id  to_stop_id duration
# 0   WALK    NaN           NaN         NaN 00:00:01
# 1    BUS  374.0       31957.0     26362.0 00:22:32
# 2   WALK    NaN           NaN         NaN 00:00:01
# 3   WALK    NaN           NaN         NaN 00:00:01
# 4    BUS  361.0       31957.0     26361.0 00:20:44
# 5   WALK    NaN           NaN         NaN 00:00:16
# 6   WALK    NaN           NaN         NaN 00:00:01
# 7    BUS  374.0       31957.0     26362.0 00:23:47
# 8   WALK    NaN           NaN         NaN 00:00:01
# 9   WALK    NaN           NaN         NaN 00:00:11
# 10   BUS  860.0       34133.0     26163.0 00:51:27
# 11  WALK    NaN           NaN         NaN 00:00:01
# 12  WALK    NaN           NaN         NaN 00:00:11
# 13   BUS  860.0       34133.0     26163.0 00:44:21
# 14  WALK    NaN           NaN         NaN 00:00:01
# 15  WALK    NaN           NaN         NaN 00:00:11
# 16   BUS  860.0       34133.0     26163.0 00:44:21
# 17  WALK    NaN           NaN         NaN 00:00:01
# 18  WALK    NaN           NaN         NaN 00:01:13
# 19   BUS  828.0       33552.0     35358.0 00:28:20
# 20  WALK    NaN           NaN         NaN 00:00:08
# 21  WALK    NaN           NaN         NaN 00:01:13
# 22   BUS  828.0       33552.0     35358.0 00:23:55
# 23  WALK    NaN           NaN         NaN 00:00:08
# 24  WALK    NaN           NaN         NaN 00:01:13
# 25   BUS  828.0       33552.0     35358.0 00:23:55
# 26  WALK    NaN           NaN         NaN 00:00:08
# 27  WALK    NaN           NaN         NaN 00:03:33
# 28  WALK    NaN           NaN         NaN 00:00:50
# 29   BUS  365.0       26347.0     29922.0 00:01:35
# ..   ...    ...           ...         ...      ...
# 54   BUS  972.0       33681.0     33375.0 00:13:02
# 55  WALK    NaN           NaN         NaN 00:00:07
# 56  WALK    NaN           NaN         NaN 00:00:05
# 57   BUS  965.0       33681.0     33375.0 00:17:51
# 58  WALK    NaN           NaN         NaN 00:00:07
# 59  WALK    NaN           NaN         NaN 00:00:18
# 60   BUS   50.0       31740.0     31769.0 00:39:21
# 61  WALK    NaN           NaN         NaN 00:00:21
# 62  WALK    NaN           NaN         NaN 00:00:18
# 63   BUS   50.0       31740.0     31769.0 00:40:09
# 64  WALK    NaN           NaN         NaN 00:00:21
# 65  WALK    NaN           NaN         NaN 00:00:18
# 66   BUS   50.0       31740.0     31769.0 00:39:30
# 67  WALK    NaN           NaN         NaN 00:00:21
# 68  WALK    NaN           NaN         NaN 00:04:06
# 69   BUS  901.0       29598.0     26722.0 00:02:53
# 70  WALK    NaN           NaN         NaN 00:00:01
# 71  WALK    NaN           NaN         NaN 00:04:16
# 72   BUS  168.0       28429.0     26722.0 00:02:53
# 73  WALK    NaN           NaN         NaN 00:00:01
# 74  WALK    NaN           NaN         NaN 00:01:45
# 75   BUS  965.0       26346.0     26722.0 00:04:03
# 76  WALK    NaN           NaN         NaN 00:00:01
# 77  WALK    NaN           NaN         NaN 00:15:38
# 78  WALK    NaN           NaN         NaN 00:02:35
# 79   BUS   40.0       30438.0     35737.0 00:05:47
# 80  WALK    NaN           NaN         NaN 00:00:26
# 81  WALK    NaN           NaN         NaN 00:00:40
# 82   BUS  644.0       28611.0     35728.0 00:01:57
# 83  WALK    NaN           NaN         NaN 00:07:24
#
# [84 rows x 11 columns]

# %%
trips_plans_df.describe(include='all')
# Out:
#               date       trip_id  itinerary_id     leg_id start_time  \
# count           84  8.400000e+01     84.000000  84.000000         84
# unique           1           NaN           NaN        NaN         84
# top     05-10-2017           NaN           NaN        NaN   07:19:28
# freq            84           NaN           NaN        NaN          1
# mean           NaN  1.085809e+12      2.047619   1.964286        NaN
# std            NaN  5.099357e+11      0.820002   0.827923        NaN
# min            NaN  2.491081e+11      1.000000   1.000000        NaN
# 25%            NaN  5.841156e+11      1.000000   1.000000        NaN
# 50%            NaN  9.534827e+11      2.000000   2.000000        NaN
# 75%            NaN  1.477469e+12      3.000000   3.000000        NaN
# max            NaN  1.709397e+12      3.000000   3.000000        NaN
#
#         end_time  mode       route  from_stop_id    to_stop_id  \
# count         84    84   27.000000     27.000000     27.000000
# unique        84     2         NaN           NaN           NaN
# top     07:26:54  WALK         NaN           NaN           NaN
# freq           1    57         NaN           NaN           NaN
# mean         NaN   NaN  556.592593  29924.037037  28627.814815
# std          NaN   NaN  323.680191   6292.226287   7718.793932
# min          NaN   NaN   40.000000  14298.000000   4664.000000
# 25%          NaN   NaN  363.000000  28520.000000  26362.000000
# 50%          NaN   NaN  535.000000  31957.000000  30052.000000
# 75%          NaN   NaN  860.000000  33681.000000  33375.000000
# max          NaN   NaN  972.000000  36881.000000  35737.000000
#
#                       duration
# count                       84
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean    0 days 00:06:51.797619
# std     0 days 00:12:16.581975
# min            0 days 00:00:01
# 25%            0 days 00:00:07
# 50%            0 days 00:00:48
# 75%     0 days 00:05:02.750000
# max            0 days 00:51:27

# %% [markdown]
# ### Read Bus Data

# %%
bus_trips_data = pd.read_csv('buste_crowd.csv')

# %%
bus_trips_data.columns
# Out:
# Index([u'route', u'tripNum', u'shapeId', u'shapeSequence', u'shapeLat',
#        u'shapeLon', u'distanceTraveledShape', u'busCode', u'gpsPointId',
#        u'gpsLat', u'gpsLon', u'distanceToShapePoint', u'timestamp',
#        u'stopPointId', u'problem', u'birthdate', u'cardTimestamp', u'lineName',
#        u'gender', u'date', u'id', u'boarding_cnt', u'alighting_cnt',
#        u'crowd_bal', u'num_pass', u'extrap_factor', u'ext_num_pass'],
#       dtype='object')

# %%
bus_trips_data['stopPointId'] = bus_trips_data['stopPointId'].astype(float)

# %%
bus_trips_data.head()
# Out:
#    route  tripNum  shapeId  shapeSequence   shapeLat   shapeLon  \
# 0  463.0        1     2846        6348468 -25.478025 -49.203033
# 1  463.0        1     2846        6348493 -25.474027 -49.209193
# 2  463.0        1     2846        6348516 -25.468650 -49.213528
# 3  463.0        1     2846        6348531 -25.464090 -49.217170
# 4  463.0        1     2846        6348545 -25.459453 -49.220872
#
#    distanceTraveledShape busCode  gpsPointId     gpsLat     ...       \
# 0               1128.772   DC087         NaN -25.478023     ...
# 1               1899.853   DC087         NaN        NaN     ...
# 2               2638.152   DC087         NaN        NaN     ...
# 3               3262.176   DC087         NaN -25.463931     ...
# 4               3896.639   DC087         NaN -25.459610     ...
#
#    lineName  gender        date             id boarding_cnt alighting_cnt  \
# 0       NaN     NaN  2017-05-10  1279900255353            0             0
# 1       NaN     NaN  2017-05-10   549755815049            0             0
# 2       NaN     NaN  2017-05-10   523986011178            0             0
# 3       NaN     NaN  2017-05-10   180388627571            0             0
# 4       NaN     NaN  2017-05-10  1142461301906            0             0
#
#   crowd_bal num_pass extrap_factor ext_num_pass
# 0         0        0      39.22807          0.0
# 1         0        0      39.22807          0.0
# 2         0        0      39.22807          0.0
# 3         0        0      39.22807          0.0
# 4         0        0      39.22807          0.0
#
# [5 rows x 27 columns]

# %%
real_trip_beginning = pd.merge(trips_plans_df,bus_trips_data, left_on=['date','route','from_stop_id'],right_on=['date','route','stopPointId'],how='inner')
real_trip_beginning = real_trip_beginning.groupby(['date','route','trip_id','itinerary_id','leg_id','from_stop_id'])

# %%
real_trip_beginning[['date','route','from_stop_id','tripNum','timestamp','start_time']]
# Out:
#             date  route  from_stop_id  tripNum timestamp start_time
# 0     2017-05-10  374.0       31957.0        1  06:24:44   07:19:28
# 1     2017-05-10  374.0       31957.0        2  07:19:18   07:19:28
# 2     2017-05-10  374.0       31957.0        3  08:22:47   07:19:28
# 3     2017-05-10  374.0       31957.0        4  09:39:23   07:19:28
# 4     2017-05-10  374.0       31957.0        5  10:36:29   07:19:28
# 5     2017-05-10  374.0       31957.0        6  11:37:44   07:19:28
# 6     2017-05-10  374.0       31957.0        7  12:45:21   07:19:28
# 7     2017-05-10  374.0       31957.0        8  13:52:44   07:19:28
# 8     2017-05-10  374.0       31957.0        9  15:03:10   07:19:28
# 9     2017-05-10  374.0       31957.0       10  16:05:30   07:19:28
# 10    2017-05-10  374.0       31957.0       11  17:11:37   07:19:28
# 11    2017-05-10  374.0       31957.0       12  18:21:58   07:19:28
# 12    2017-05-10  374.0       31957.0        1  22:56:45   07:19:28
# 13    2017-05-10  374.0       31957.0        2  06:48:23   07:19:28
# 14    2017-05-10  374.0       31957.0        3  07:53:17   07:19:28
# 15    2017-05-10  374.0       31957.0        4  08:56:41   07:19:28
# 16    2017-05-10  374.0       31957.0        5  17:25:26   07:19:28
# 17    2017-05-10  374.0       31957.0        6  18:41:48   07:19:28
# 18    2017-05-10  374.0       31957.0        7  19:57:30   07:19:28
# 19    2017-05-10  374.0       31957.0        8  20:57:35   07:19:28
# 20    2017-05-10  374.0       31957.0        9  21:56:02   07:19:28
# 21    2017-05-10  374.0       31957.0        1  07:37:59   07:19:28
# 22    2017-05-10  374.0       31957.0        2  08:47:39   07:19:28
# 23    2017-05-10  374.0       31957.0        3  09:56:00   07:19:28
# 24    2017-05-10  374.0       31957.0        4  10:56:10   07:19:28
# 25    2017-05-10  374.0       31957.0        5  12:01:13   07:19:28
# 26    2017-05-10  374.0       31957.0        6  13:09:36   07:19:28
# 27    2017-05-10  374.0       31957.0        7  14:14:07   07:19:28
# 28    2017-05-10  374.0       31957.0        8  15:20:57   07:19:28
# 29    2017-05-10  374.0       31957.0        9  16:28:11   07:19:28
# ...          ...    ...           ...      ...       ...        ...
# 1401  2017-05-10   40.0       30438.0        4  13:32:55   17:39:00
# 1402  2017-05-10   40.0       30438.0        5  16:12:13   17:39:00
# 1403  2017-05-10   40.0       30438.0        1  22:39:38   17:39:00
# 1404  2017-05-10   40.0       30438.0        2  06:18:43   17:39:00
# 1405  2017-05-10  644.0       28611.0        1  05:47:19   17:54:00
# 1406  2017-05-10  644.0       28611.0        2  06:26:27   17:54:00
# 1407  2017-05-10  644.0       28611.0        3  07:08:33   17:54:00
# 1408  2017-05-10  644.0       28611.0        4  07:55:54   17:54:00
# 1409  2017-05-10  644.0       28611.0        5  08:32:20   17:54:00
# 1410  2017-05-10  644.0       28611.0        6  09:14:51   17:54:00
# 1411  2017-05-10  644.0       28611.0        7  09:52:41   17:54:00
# 1412  2017-05-10  644.0       28611.0        8  10:28:58   17:54:00
# 1413  2017-05-10  644.0       28611.0        9  11:09:42   17:54:00
# 1414  2017-05-10  644.0       28611.0       10  11:48:52   17:54:00
# 1415  2017-05-10  644.0       28611.0       11  12:29:36   17:54:00
# 1416  2017-05-10  644.0       28611.0       12  13:10:49   17:54:00
# 1417  2017-05-10  644.0       28611.0       13  13:49:21   17:54:00
# 1418  2017-05-10  644.0       28611.0       14  14:30:29   17:54:00
# 1419  2017-05-10  644.0       28611.0       15  15:12:04   17:54:00
# 1420  2017-05-10  644.0       28611.0       16  15:49:36   17:54:00
# 1421  2017-05-10  644.0       28611.0       17  16:31:33   17:54:00
# 1422  2017-05-10  644.0       28611.0       18  17:14:02   17:54:00
# 1423  2017-05-10  644.0       28611.0       19  17:59:20   17:54:00
# 1424  2017-05-10  644.0       28611.0       20  18:49:20   17:54:00
# 1425  2017-05-10  644.0       28611.0       21  19:27:07   17:54:00
# 1426  2017-05-10  644.0       28611.0       22  20:04:06   17:54:00
# 1427  2017-05-10  644.0       28611.0       23  20:43:52   17:54:00
# 1428  2017-05-10  644.0       28611.0       24  21:35:44   17:54:00
# 1429  2017-05-10  644.0       28611.0       25  22:27:15   17:54:00
# 1430  2017-05-10  644.0       28611.0       26  23:29:39   17:54:00
#
# [1431 rows x 6 columns]

# %%
trips_plans_df.head()
# Out:
#          trip_id  itinerary_id  leg_id     start_time       end_time  mode  \
# 0  1434519077089             1       1  1494411566000  1494411567000  WALK
# 1  1434519077089             1       2  1494411568000  1494412920000   BUS
# 2  1434519077089             1       3  1494412921000  1494412922000  WALK
# 3  1434519077089             2       1  1494412034000  1494412035000  WALK
# 4  1434519077089             2       2  1494412036000  1494413280000   BUS
#
#   route from_stop_id to_stop_id duration
# 0               None       None 00:00:01
# 1   374        31957      26362 00:22:32
# 2               None       None 00:00:01
# 3               None       None 00:00:01
# 4   361        31957      26361 00:20:44

# %%
for index, row in trips_plans_df.iterrows():
    if row['mode'] == 'BUS':
        bus_trips_data.filter((bus_trips_data.route == row['route']) & 
                              (int(bus_trips_data.stopPointId) == int(row['from_stop_id']))
# Out:
#   File "<ipython-input-173-9376cbc206d6>", line 5
#
#     ^
# SyntaxError: invalid syntax
